# %%
# !aws s3 ls s3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/
# Out:
#                            PRE amazon_fashion_interaction.csv/
#                            PRE amazon_fashion_interaction.parquet/
#                            PRE amazon_fashion_interaction.small.parquet/
#                            PRE amazon_fashion_item.csv/
#                            PRE amazon_fashion_item.parquet/
#                            PRE amazon_fashion_item.small.parquet/
#                            PRE amazon_fashion_user.csv/
#                            PRE amazon_fashion_user.parquet/
#                            PRE amazon_fashion_user.small.parquet/
# 2022-09-08 14:11:37 3247339254 amazon_fashion_product.json
# 2022-09-08 14:13:55 3059298908 amazon_fashion_review.json

# %%
import os
import subprocess
import yaml
import argparse
import sys 
import importlib
import metaspore as ms
import pandas as pd
import warnings
import pyspark.sql.functions as F

warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
def init_spark(local, app_name, batch_size, worker_count, server_count,
               worker_memory, server_memory, coordinator_memory, **kwargs):
    subprocess.run(['zip', '-r', os.getcwd() + '/python.zip', 'python'], cwd='../../../')
    spark_confs={
        "spark.kubernetes.namespace":"wanggen",
        "spark.network.timeout":"500",
        "spark.submit.pyFiles":"python.zip",
        "spark.ui.showConsoleProgress": "true",
        "spark.kubernetes.executor.deleteOnTermination":"true",
    }
    spark = ms.spark.get_session(
        local=local,
        app_name=app_name,
        batch_size=batch_size,
        worker_count=worker_count,
        server_count=server_count,
        worker_memory=worker_memory,
        server_memory=server_memory,
        coordinator_memory=coordinator_memory,
        spark_confs=spark_confs)
    sc = spark.sparkContext
    print('Debug -- spark init')
    print('Debug -- version:', sc.version)   
    print('Debug -- applicaitonId:', sc.applicationId)
    print('Debug -- uiWebUrl:', sc.uiWebUrl)
    return spark

def stop_spark(spark):
    print('Debug -- spark stop')
    spark.sparkContext.stop()

def read_dataset(spark, dataset_path):
    dataset = spark.read.json(dataset_path)
    print('Debug -- item dataset count:', dataset.count())
    return dataset

# %%
# spark
params = {}
params['local'] = False
params['app_name'] = 'Amazon Fashion Dataset'
params['batch_size'] = 512
params['worker_count'] = 4
params['worker_cpu'] = 4
params['server_count'] = 4
params['server_cpu'] = 4
params['worker_memory'] = '6G'
params['server_memory'] = '6G'
params['coordinator_memory'] = '2G'

# input files
product_path = 's3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/amazon_fashion_product.json'
review_path = 's3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/amazon_fashion_review.json'
item2image_path = 's3://dmetasoul-bucket/xwb/tmp/amazon_fashion_id2img.valid.tsv'
category_valid_path = 's3://dmetasoul-bucket/xwb/tmp/amazon_fashion_category_valid.parquet'

# output files
user_path = 's3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/amazon_fashion_user.parquet'
item_path = 's3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/amazon_fashion_item.parquet'
interaction_path = 's3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/amazon_fashion_interaction.parquet'

spark = init_spark(**params)
# Out:
# updating: python/ (stored 0%)
# updating: python/algos/ (stored 0%)
# updating: python/algos/deepfm_net.py (deflated 69%)
# updating: python/algos/feature/ (stored 0%)
# updating: python/algos/feature/woe_encoder.py (deflated 64%)
# updating: python/algos/feature/.ipynb_checkpoints/ (stored 0%)
# updating: python/algos/feature/.ipynb_checkpoints/target_encoder-checkpoint.py (deflated 51%)
# updating: python/algos/feature/sequential_encoder.py (deflated 60%)
# updating: python/algos/feature/target_encoder.py (deflated 51%)
# updating: python/algos/feature/neg_sampler.py (deflated 66%)
# updating: python/algos/feature/__pycache__/ (stored 0%)
# updating: python/algos/feature/__pycache__/woe_encoder.cpython-38.pyc (deflated 43%)
# updating: python/algos/feature/__pycache__/target_encoder.cpython-38.pyc (deflated 36%)
# updating: python/algos/feature/__pycache__/__init__.cpython-38.pyc (deflated 29%)
# updating: python/algos/feature/__pycache__/sequential_encoder.cpython-38.pyc (deflated 53%)
# updating: python/algos/feature/__pycache__/neg_sampler.cpython-38.pyc (deflated 50%)
# updating: python/algos/feature/__init__.py (deflated 41%)
# updating: python/algos/dcn_v2_net.py (deflated 75%)
# updating: python/algos/autoint_net.py (deflated 70%)
# updating: python/algos/twotower/ (stored 0%)
# updating: python/algos/twotower/retrieval_metric.py (deflated 68%)
# updating: python/algos/twotower/simplex/ (stored 0%)
# updating: python/algos/twotower/simplex/simplex_agent.py (deflated 64%)
# updating: python/algos/twotower/simplex/simplex_net.py (deflated 71%)
# updating: python/algos/twotower/simplex/__init__.py (deflated 39%)
# updating: python/algos/twotower/two_tower_retrieval.py (deflated 81%)
# updating: python/algos/twotower/__init__.py (deflated 40%)
# updating: python/algos/twotower/dssm/ (stored 0%)
# updating: python/algos/twotower/dssm/dssm_agent.py (deflated 72%)
# updating: python/algos/twotower/dssm/dssm_net.py (deflated 78%)
# updating: python/algos/twotower/dssm/__init__.py (deflated 41%)
# updating: python/algos/pipeline/ (stored 0%)
# updating: python/algos/pipeline/deep_ctr.py (deflated 77%)
# updating: python/algos/pipeline/utils/ (stored 0%)
# updating: python/algos/pipeline/utils/class_utils.py (deflated 52%)
# updating: python/algos/pipeline/utils/dict_utils.py (deflated 39%)
# updating: python/algos/pipeline/utils/constants.py (deflated 42%)
# updating: python/algos/pipeline/utils/__pycache__/ (stored 0%)
# updating: python/algos/pipeline/utils/__pycache__/constants.cpython-38.pyc (deflated 30%)
# updating: python/algos/pipeline/utils/__pycache__/logger.cpython-38.pyc (deflated 30%)
# updating: python/algos/pipeline/utils/__pycache__/dict_utils.cpython-38.pyc (deflated 33%)
# updating: python/algos/pipeline/utils/__pycache__/__init__.cpython-38.pyc (deflated 23%)
# updating: python/algos/pipeline/utils/__pycache__/class_utils.cpython-38.pyc (deflated 37%)
# updating: python/algos/pipeline/utils/__init__.py (deflated 38%)
# updating: python/algos/pipeline/utils/logger.py (deflated 48%)
# updating: python/algos/pipeline/i2i_retrieval.py (deflated 75%)
# updating: python/algos/pipeline/data_loader.py (deflated 67%)
# updating: python/algos/pipeline/popular_retrieval.py (deflated 68%)
# updating: python/algos/pipeline/.ipynb_checkpoints/ (stored 0%)
# updating: python/algos/pipeline/.ipynb_checkpoints/deep_ctr-checkpoint.py (deflated 77%)
# updating: python/algos/pipeline/.ipynb_checkpoints/mongodb_dumper-checkpoint.py (deflated 62%)
# updating: python/algos/pipeline/.ipynb_checkpoints/init_spark-checkpoint.py (deflated 61%)
# updating: python/algos/pipeline/.ipynb_checkpoints/common_validators-checkpoint.py (deflated 66%)
# updating: python/algos/pipeline/.ipynb_checkpoints/i2i_retrieval-checkpoint.py (deflated 75%)
# updating: python/algos/pipeline/.ipynb_checkpoints/popular_retrieval-checkpoint.py (deflated 68%)
# updating: python/algos/pipeline/mongodb_dumper.py (deflated 62%)
# updating: python/algos/pipeline/common_validators.py (deflated 66%)
# updating: python/algos/pipeline/__pycache__/ (stored 0%)
# updating: python/algos/pipeline/__pycache__/i2i_retrieval.cpython-38.pyc (deflated 52%)
# updating: python/algos/pipeline/__pycache__/deep_ctr.cpython-38.pyc (deflated 53%)
# updating: python/algos/pipeline/__pycache__/popular_retrieval.cpython-38.pyc (deflated 46%)
# updating: python/algos/pipeline/__pycache__/mongodb_dumper.cpython-38.pyc (deflated 42%)
# updating: python/algos/pipeline/__pycache__/common_validators.cpython-38.pyc (deflated 55%)
# updating: python/algos/pipeline/__pycache__/data_loader.cpython-38.pyc (deflated 48%)
# updating: python/algos/pipeline/__pycache__/init_spark.cpython-38.pyc (deflated 41%)
# updating: python/algos/pipeline/__pycache__/__init__.cpython-38.pyc (deflated 43%)
# updating: python/algos/pipeline/__init__.py (deflated 52%)
# updating: python/algos/pipeline/init_spark.py (deflated 61%)
# updating: python/algos/tuner/ (stored 0%)
# updating: python/algos/tuner/base_tuner.py (deflated 70%)
# updating: python/algos/dcn_net.py (deflated 69%)
# updating: python/algos/pnn_net.py (deflated 70%)
# updating: python/algos/multitask/ (stored 0%)
# updating: python/algos/multitask/esmm/ (stored 0%)
# updating: python/algos/multitask/esmm/esmm_agent.py (deflated 74%)
# updating: python/algos/multitask/esmm/esmm_net.py (deflated 69%)
# updating: python/algos/multitask/__init__.py (deflated 43%)
# updating: python/algos/multitask/mmoe/ (stored 0%)
# updating: python/algos/multitask/mmoe/mmoe_net.py (deflated 75%)
# updating: python/algos/multitask/mmoe/mmoe_agent.py (deflated 70%)
# updating: python/algos/xdeepfm_net.py (deflated 71%)
# updating: python/algos/layers.py (deflated 79%)
# updating: python/algos/item_cf_retrieval.py (deflated 77%)
# updating: python/algos/fwfm_net.py (deflated 69%)
# updating: python/algos/ffm_net.py (deflated 71%)
# updating: python/algos/__pycache__/ (stored 0%)
# updating: python/algos/__pycache__/layers.cpython-38.pyc (deflated 59%)
# updating: python/algos/__pycache__/widedeep_net.cpython-38.pyc (deflated 41%)
# updating: python/algos/__pycache__/item_cf_retrieval.cpython-38.pyc (deflated 54%)
# updating: python/algos/__pycache__/__init__.cpython-38.pyc (deflated 21%)
# updating: python/algos/widedeep_net.py (deflated 68%)
# updating: python/algos/sequential/ (stored 0%)
# updating: python/algos/sequential/din/ (stored 0%)
# updating: python/algos/sequential/din/din_net.py (deflated 76%)
# updating: python/algos/sequential/dien/ (stored 0%)
# updating: python/algos/sequential/dien/dien_net.py (deflated 79%)
# updating: python/algos/sequential/dien/dien_agent.py (deflated 61%)
# updating: python/algos/sequential/__init__.py (deflated 41%)
# updating: python/algos/__init__.py (deflated 38%)
# updating: python/tests/ (stored 0%)
# updating: python/tests/mnist_mlp_eval.py (deflated 57%)
# updating: python/tests/mnist_mlp.py (deflated 59%)
# updating: python/tests/sparse_mlp_export_demo.py (deflated 64%)
# updating: python/tests/sparse_wdl_grpc_test.py (deflated 52%)
# updating: python/tests/sparse_two_tower_export_demo.py (deflated 73%)
# updating: python/tests/dense_xgboost.py (deflated 49%)
# updating: python/tests/verify_java_tensor_serde.py (deflated 42%)
# updating: python/tests/requirements.txt (deflated 24%)
# updating: python/tests/sparse_wdl_export_test.py (deflated 66%)
# updating: python/tests/sparse_wdl_export_demo.py (deflated 64%)
# updating: python/tests/dense_xgboost_grpc_test.py (deflated 44%)
# updating: python/tests/embedding_bag_export.py (deflated 61%)
# updating: python/tests/two_tower_retrieval_milvus.py (deflated 81%)
# updating: python/ps/ (stored 0%)
# updating: python/ps/job.py (deflated 81%)
# updating: python/ps/__init__.py (deflated 42%)
# updating: python/scripts/ (stored 0%)
# updating: python/scripts/preprocessing/ (stored 0%)
# updating: python/scripts/preprocessing/example_requirements.txt (stored 0%)
# updating: python/scripts/preprocessing/preprocessor_service.py (deflated 69%)
# updating: python/scripts/preprocessing/example_preprocessor.py (deflated 54%)
# updating: python/scripts/preprocessing/test_example_preprocessor.py (deflated 51%)
# updating: python/scripts/consul/ (stored 0%)
# updating: python/scripts/consul/Dockerfile (deflated 44%)
# updating: python/scripts/consul/consul_watch_load.py (deflated 72%)
# updating: python/scripts/consul/build.sh (deflated 30%)
# updating: python/scripts/consul/create_consul_watch.sh (deflated 17%)
# updating: python/metaspore/ (stored 0%)
# updating: python/metaspore/url_utils.py (deflated 51%)
# updating: python/metaspore/estimator.py (deflated 85%)
# updating: python/metaspore/model.py (deflated 81%)
# updating: python/metaspore/distributed_trainer.py (deflated 76%)
# updating: python/metaspore/ps_launcher.py (deflated 68%)
# updating: python/metaspore/experiment.py (deflated 76%)
# updating: python/metaspore/distributed_tensor.py (deflated 80%)
# updating: python/metaspore/schema_utils.py (deflated 70%)
# updating: python/metaspore/nn/ (stored 0%)
# updating: python/metaspore/nn/wide_and_deep.py (deflated 75%)
# updating: python/metaspore/nn/fm.py (deflated 47%)
# updating: python/metaspore/nn/normalization.py (deflated 61%)
# updating: python/metaspore/nn/deep_fm.py (deflated 70%)
# updating: python/metaspore/nn/__init__.py (deflated 41%)
# updating: python/metaspore/s3_utils.py (deflated 73%)
# updating: python/metaspore/file_utils.py (deflated 69%)
# updating: python/metaspore/embedding.py (deflated 81%)
# updating: python/metaspore/agent.py (deflated 77%)
# updating: python/metaspore/metric.py (deflated 78%)
# updating: python/metaspore/feature_group.py (deflated 58%)
# updating: python/metaspore/job_utils.py (deflated 47%)
# updating: python/metaspore/initializer.py (deflated 76%)
# updating: python/metaspore/demo.py (deflated 54%)
# updating: python/metaspore/two_tower_ranking.py (deflated 80%)
# updating: python/metaspore/shell_utils.py (deflated 65%)
# updating: python/metaspore/output.py (deflated 56%)
# updating: python/metaspore/network_utils.py (deflated 52%)
# updating: python/metaspore/loss_utils.py (deflated 40%)
# updating: python/metaspore/spark.py (deflated 71%)
# updating: python/metaspore/name_utils.py (deflated 37%)
# updating: python/metaspore/two_tower_retrieval.py (deflated 83%)
# updating: python/metaspore/updater.py (deflated 81%)
# updating: python/metaspore/patching_pickle.py (deflated 72%)
# updating: python/metaspore/cast.py (deflated 60%)
# updating: python/metaspore/stack_trace_utils.py (deflated 43%)
# updating: python/metaspore/__init__.py (deflated 68%)
# updating: python/metaspore/swing_retrieval.py (deflated 79%)
# updating: python/metaspore/compat/ (stored 0%)
# updating: python/metaspore/compat/ps/ (stored 0%)
# updating: python/metaspore/compat/ps/__init__.py (deflated 66%)
# updating: python/metaspore/compat/__init__.py (deflated 52%)
# updating: python/metaspore/input.py (deflated 59%)
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/lib/python3.8/dist-packages/pyspark/jars/spark-unsafe_2.12-3.1.2.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 22/10/09 13:35:37 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Debug -- spark init
# Debug -- version: 3.1.2
# Debug -- applicaitonId: spark-application-1665293739682
# Debug -- uiWebUrl: http://172.16.0.156:4040

# %%
product_dataset = read_dataset(spark, product_path)
product_dataset = product_dataset.distinct()
# Out:
# [Stage 1:======================================================>  (24 + 1) / 25]
# Debug -- item dataset count: 2685059

# %%
product_dataset.printSchema()
# Out:
# root
#  |-- brand: string (nullable = true)
#  |-- category: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- category_levels: long (nullable = true)
#  |-- description: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- image: string (nullable = true)
#  |-- item_id: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- url: string (nullable = true)

# %%
item2image_df = spark.read.option("delimiter", "\t").csv(item2image_path)
item2image_df = item2image_df.withColumnRenamed('_c0', 'item_id')
item2image_df = item2image_df.withColumnRenamed('_c1', 'image')
item2image_df = item2image_df.distinct()
item2image_df.printSchema()
item2image_df.show(20, False)
# Out:
# root
#  |-- item_id: string (nullable = true)
#  |-- image: string (nullable = true)
# [Stage 4:>                                                          (0 + 8) / 8]
# +----------+----------------------------------------------------------------+
# |item_id   |image                                                           |
# +----------+----------------------------------------------------------------+
# |B00L2MGOOQ|https://images-na.ssl-images-amazon.com/images/I/51NfBS18gmL.jpg|
# |B00L365V68|https://images-na.ssl-images-amazon.com/images/I/31RM0BVDz0L.jpg|
# |B00L398ZPY|https://images-na.ssl-images-amazon.com/images/I/61QB2H9lzlL.jpg|
# |B00L3CTP9Q|https://images-na.ssl-images-amazon.com/images/I/31AggIZ0QAL.jpg|
# |B00L3GNUI4|https://images-na.ssl-images-amazon.com/images/I/41y0MnBi9EL.jpg|
# |B00L3MTAO6|https://images-na.ssl-images-amazon.com/images/I/31m2ykMCfhL.jpg|
# |B00L3TYFBM|https://images-na.ssl-images-amazon.com/images/I/41buRfTf6zL.jpg|
# |B00L3VGP04|https://images-na.ssl-images-amazon.com/images/I/21uIMDohqJL.jpg|
# |B00L3YEZF8|https://images-na.ssl-images-amazon.com/images/I/313wI-77gnL.jpg|
# |B00L43LJYI|https://images-na.ssl-images-amazon.com/images/I/518lbqO86xL.jpg|
# |B00L46NAS8|https://images-na.ssl-images-amazon.com/images/I/31-Y1uLanjL.jpg|
# |B00L473PTQ|https://images-na.ssl-images-amazon.com/images/I/41PgfUOIhTL.jpg|
# |B00L4F63JW|https://images-na.ssl-images-amazon.com/images/I/31LZJwy4jkL.jpg|
# |B00L4FONUI|https://images-na.ssl-images-amazon.com/images/I/41PY-YC-osL.jpg|
# |B00L4GDW9K|https://images-na.ssl-images-amazon.com/images/I/41uTMO5EkYL.jpg|
# |B00L4GPOZA|https://images-na.ssl-images-amazon.com/images/I/51wLNsL1BeL.jpg|
# |B00L4H7E70|https://images-na.ssl-images-amazon.com/images/I/51-970FhvQL.jpg|
# |B00L4HGNR2|https://images-na.ssl-images-amazon.com/images/I/61CTl71-xoL.jpg|
# |B00L4HVPYI|https://images-na.ssl-images-amazon.com/images/I/51vdQtk3hgL.jpg|
# |B00L4I4ILO|https://images-na.ssl-images-amazon.com/images/I/41yK243UtYL.jpg|
# +----------+----------------------------------------------------------------+
# only showing top 20 rows

# %%
category_valid = spark.read.parquet(category_valid_path)
category_valid.printSchema()
category_valid.show(20, False)
# Out:
# root
#  |-- category: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- category_path: string (nullable = true)
#  |-- valid_level: long (nullable = true)
# [Stage 7:>                                                          (0 + 1) / 1]
# +------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------+-----------+
# |category                                                                                        |category_path                                                                                 |valid_level|
# +------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------+-----------+
# |[Clothing, Shoes & Jewelry, Luggage & Travel Gear, Umbrellas, Folding Umbrellas]                |Clothing, Shoes & Jewelry->Luggage & Travel Gear->Umbrellas->Folding Umbrellas                |3          |
# |[Clothing, Shoes & Jewelry, Men, Accessories, Hats & Caps, Baseball Caps]                       |Clothing, Shoes & Jewelry->Men->Accessories->Hats & Caps->Baseball Caps                       |0          |
# |[Clothing, Shoes & Jewelry, Women, Clothing, Dresses, Casual]                                   |Clothing, Shoes & Jewelry->Women->Clothing->Dresses->Casual                                   |2          |
# |[Clothing, Shoes & Jewelry, Women, Clothing, Dresses, Wedding Dresses]                          |Clothing, Shoes & Jewelry->Women->Clothing->Dresses->Wedding Dresses                          |2          |
# |[Clothing, Shoes & Jewelry, Traditional & Cultural Wear, European]                              |Clothing, Shoes & Jewelry->Traditional & Cultural Wear->European                              |0          |
# |[Clothing, Shoes & Jewelry, Women, Clothing, Tops, Tees & Blouses, Blouses & Button-Down Shirts]|Clothing, Shoes & Jewelry->Women->Clothing->Tops, Tees & Blouses->Blouses & Button-Down Shirts|1          |
# |[Clothing, Shoes & Jewelry, Women, Clothing, Dresses, Cocktail]                                 |Clothing, Shoes & Jewelry->Women->Clothing->Dresses->Cocktail                                 |2          |
# |[Clothing, Shoes & Jewelry, Men, Clothing, Shorts, Cargo]                                       |Clothing, Shoes & Jewelry->Men->Clothing->Shorts->Cargo                                       |1          |
# |[Clothing, Shoes & Jewelry, Women, Clothing, Socks & Hosiery, Casual Socks]                     |Clothing, Shoes & Jewelry->Women->Clothing->Socks & Hosiery->Casual Socks                     |2          |
# |[Clothing, Shoes & Jewelry, Women, Jewelry, Necklaces, Chain Material: Lace]                    |Clothing, Shoes & Jewelry->Women->Jewelry->Necklaces->Chain Material: Lace                    |3          |
# |[Clothing, Shoes & Jewelry, Women, Shoes, Fashion Sneakers, canvas]                             |Clothing, Shoes & Jewelry->Women->Shoes->Fashion Sneakers->canvas                             |3          |
# |[Clothing, Shoes & Jewelry, Men, Jewelry, Rings, Colour: Black and Red]                         |Clothing, Shoes & Jewelry->Men->Jewelry->Rings->Colour: Black and Red                         |3          |
# |[Clothing, Shoes & Jewelry, Men, Accessories]                                                   |Clothing, Shoes & Jewelry->Men->Accessories                                                   |0          |
# |[Clothing, Shoes & Jewelry, Novelty & More, Clothing, Novelty, Men]                             |Clothing, Shoes & Jewelry->Novelty & More->Clothing->Novelty->Men                             |0          |
# |[Clothing, Shoes & Jewelry, Women, Handbags & Wallets, Shoulder Bags]                           |Clothing, Shoes & Jewelry->Women->Handbags & Wallets->Shoulder Bags                           |0          |
# |[Clothing, Shoes & Jewelry, Women, Clothing, Swimsuits & Cover Ups, Bikinis]                    |Clothing, Shoes & Jewelry->Women->Clothing->Swimsuits & Cover Ups->Bikinis                    |0          |
# |[Clothing, Shoes & Jewelry, Women, Shoes, Rubber, Slip on boat shoes style]                     |Clothing, Shoes & Jewelry->Women->Shoes->Rubber->Slip on boat shoes style                     |3          |
# |[Clothing, Shoes & Jewelry, Boys, Clothing, Tops & Tees, Tees]                                  |Clothing, Shoes & Jewelry->Boys->Clothing->Tops & Tees->Tees                                  |4          |
# |[Clothing, Shoes & Jewelry, Novelty & More, Clothing, Novelty, Girls]                           |Clothing, Shoes & Jewelry->Novelty & More->Clothing->Novelty->Girls                           |0          |
# |[Clothing, Shoes & Jewelry, Novelty & More, Clothing, Novelty, Women]                           |Clothing, Shoes & Jewelry->Novelty & More->Clothing->Novelty->Women                           |0          |
# +------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------+-----------+
# only showing top 20 rows

# %%
product_dataset = product_dataset.drop('image')
product_dataset = product_dataset.join(item2image_df, on='item_id', how='leftouter')

product_dataset = product_dataset.filter(F.col("image").isNotNull())
product_dataset = product_dataset.filter(F.col("image") != '')
product_dataset = product_dataset.filter(F.col("title") != '')
product_dataset = product_dataset.filter(F.length(F.col("title")) <= 300)

product_dataset = product_dataset.withColumn('category_path', F.concat_ws('->', 'category'))
product_dataset = category_valid.filter(F.col('valid_level') > 0).select('category_path').distinct()\
                    .join(product_dataset, on='category_path', how='inner').drop('category_path')

product_dataset.limit(20).toPandas()
print(product_dataset.count())
# Out:
# [Stage 22:====================================================> (193 + 1) / 200]
# 1123952

# %%
review_dataset = read_dataset(spark, review_path)
# Out:
# [Stage 25:=====================================================>  (22 + 1) / 23]
# Debug -- item dataset count: 32292099

# %%
import pyspark.sql.functions as F
product_subset = product_dataset.where(F.array_contains(F.col("category"), 'Clothing') & 
                                       F.array_contains(F.col('category'), 'Women'))

# %%
product_subset.limit(10).toPandas()
# Out:
#       item_id            brand  \
# 0  B0002LK9UI             Alia
# 1  B0002NYPWO
# 2  B0007V0ZYS         Hot Fash
# 3  B000FZVLQW
# 4  B0018QSSKO             Mudd
# 5  B001E77NBW
# 6  B001FWYZ62
# 7  B001GCVL4K
# 8  B001SYRSDE  eVogues Apparel
# 9  B00243FOIY
#
#                                             category  category_levels  \
# 0  [Clothing, Shoes & Jewelry, Women, Clothing, P...                5
# 1  [Clothing, Shoes & Jewelry, Women, Clothing, S...                5
# 2  [Clothing, Shoes & Jewelry, Women, Clothing, D...                5
# 3  [Clothing, Shoes & Jewelry, Women, Clothing, C...                5
# 4  [Clothing, Shoes & Jewelry, Women, Clothing, S...                5
# 5  [Clothing, Shoes & Jewelry, Women, Clothing, C...                5
# 6  [Clothing, Shoes & Jewelry, Women, Clothing, T...                5
# 7  [Clothing, Shoes & Jewelry, Women, Clothing, J...                5
# 8  [Clothing, Shoes & Jewelry, Women, Clothing, T...                5
# 9  [Clothing, Shoes & Jewelry, Women, Clothing, D...                5
#
#                                          description           price  \
# 0  [Ultra soft Feathertouch crafts this easy-care...
# 1  [Feel absolutely fabulous with these Hanes pan...  $3.93 - $34.15
# 2  [Stop him in his tracks with this stunning hal...
# 3  [Fashion and funtion meet in this stylish reve...
# 4  [MUDD Junior's Striped Short is the perfect li...
# 5  [Offering products for every aspect of the act...
# 6               [Stylish clothes for everyday wear.]
# 7  [Stretch extend tab embroidered back pocket jean]
# 8                                               None
# 9  [A.Byer Bold blossom floral fitted dress. This...
#
#                                                title  \
# 0                          Feathertouch Pull-On Pant
# 1  Hanes Women's Absolutely Ultra Sheer Control T...
# 2  Sleeveless Flattering Skirt Stylish Formal Hal...
# 3    Columbia Sportswear Women's Double the Fun Vest
# 4                         MUDD Juniors Striped Short
# 5                 Roxy Juniors Calypso Hooded Fleece
# 6                  XOXO Juniors Fold And Tuck Blouse
# 7                Gloria Vanderbilt Women's Toby Jean
# 8  eVogues Women's Sexy O-Ring Necklace Sleeveles...
# 9  A. Byer Juniors Bold Blossom Floral Print Belt...
#
#                                     url  \
# 0  https://www.amazon.com/dp/B0002LK9UI
# 1  https://www.amazon.com/dp/B0002NYPWO
# 2  https://www.amazon.com/dp/B0007V0ZYS
# 3  https://www.amazon.com/dp/B000FZVLQW
# 4  https://www.amazon.com/dp/B0018QSSKO
# 5  https://www.amazon.com/dp/B001E77NBW
# 6  https://www.amazon.com/dp/B001FWYZ62
# 7  https://www.amazon.com/dp/B001GCVL4K
# 8  https://www.amazon.com/dp/B001SYRSDE
# 9  https://www.amazon.com/dp/B00243FOIY
#
#                                                image
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
# 3  https://images-na.ssl-images-amazon.com/images...
# 4  https://images-na.ssl-images-amazon.com/images...
# 5  https://images-na.ssl-images-amazon.com/images...
# 6  https://images-na.ssl-images-amazon.com/images...
# 7  https://images-na.ssl-images-amazon.com/images...
# 8  https://images-na.ssl-images-amazon.com/images...
# 9  https://images-na.ssl-images-amazon.com/images...

# %%
review_dataset.limit(10).toPandas()
# Out:
#       item_id  rating   timestamp         user_id
# 0  B006CBAOQ6     1.0  1424304000  A1AG1NX2VXKY2T
# 1  B006CBAOQ6     5.0  1424304000  A3B1USQFGCWH15
# 2  B006CBAOQ6     5.0  1424044800   AXL1XBXHN1AQ1
# 3  B006CBAOQ6     4.0  1424044800   AP3CLPX9J5PAV
# 4  B006CBAOQ6     4.0  1423958400  A3REHYIAGCIFTB
# 5  B006CBAOQ6     5.0  1423267200  A2YICSVD18YH1R
# 6  B006CBAOQ6     3.0  1423094400  A3U28J1QPXC8SC
# 7  B006CBAOQ6     4.0  1422489600   ADZOZ3PZ6RLL7
# 8  B006CBAOQ6     5.0  1422489600  A1CSXM2VZLZPPA
# 9  B006CBAOQ6     5.0  1422316800  A2U3SUU8SNP8IW

# %%
review_dataset
# Out:
# DataFrame[item_id: string, rating: double, timestamp: bigint, user_id: string]

# %%
review_dataset.registerTempTable('review_dataset') 
product_subset.registerTempTable('product_subset')
query ="""
select 
    ta.user_id
from
(
    select
        ta.user_id,
        count(distinct ta.item_id, ta.timestamp) as review_count
    from
        review_dataset ta
    join
        product_subset tb
    on 
        ta.item_id=tb.item_id
    group by ta.user_id
) ta
where ta.review_count >= 20
"""
user_5core = spark.sql(query)

# %%
user_5core.count()
# Out:
# 1212

# %%
user_5core.limit(20).toPandas()
# Out:
#            user_id
# 0    AENSGPP7TSU4V
# 1   A3KRRVHYFDDU59
# 2   A3VG66KUM1WH4Z
# 3   A2SXQ8QP7LORDO
# 4   A2XTRTRAPHO821
# 5   A309G6ZUPNXXZU
# 6    A2GXHN4EU46RM
# 7   A220STV60KRN7W
# 8    A1S5OQUVLF7HK
# 9   A1FEMGOF4SS3PY
# 10  A1WUIYOGBGSRR7
# 11  A16ZROYKG27HYY
# 12  A214L1PZ91H4BV
# 13  A1EKI69RSP2NSK
# 14   AIST10GM4T13H
# 15  A1GU8OU7AOWNQ3
# 16  A35AV3FQTJEQ0F
# 17  A2Q6VSR4GMNHAG
# 18  A24B2LZWNSTF12
# 19  A2C4ZV70PRW69J

# %%
user_5core.registerTempTable('user_5core')

query ="""
select distinct
    tb.*
from
    user_5core ta
join
    review_dataset tb
on ta.user_id=tb.user_id
"""
review_5core = spark.sql(query)

# %%
review_5core.count()
# Out:
# 105155

# %%
review_5core.limit(20).toPandas()
# Out:
#        item_id  rating   timestamp         user_id
# 0   B000B6LO6W     5.0  1521417600  A3KRRVHYFDDU59
# 1   B000H0V944     4.0  1392508800  A3KRRVHYFDDU59
# 2   B01CGV1FTK     5.0  1527552000  A3KRRVHYFDDU59
# 3   B01D1R5Q3O     4.0  1521417600  A3KRRVHYFDDU59
# 4   B01DBJQB18     5.0  1521417600  A3KRRVHYFDDU59
# 5   B01E9GP8RK     5.0  1473897600  A3KRRVHYFDDU59
# 6   B01FJ8OJK4     5.0  1510704000  A3KRRVHYFDDU59
# 7   B01FY9XN00     5.0  1527552000  A3KRRVHYFDDU59
# 8   B00OA0HIHO     5.0  1472428800  A3KRRVHYFDDU59
# 9   B00Q5L44I2     5.0  1472428800  A3KRRVHYFDDU59
# 10  B00STNTL7S     2.0  1453507200  A3KRRVHYFDDU59
# 11  B00STO4EB0     3.0  1473292800  A3KRRVHYFDDU59
# 12  B006Z8FYVG     1.0  1454457600  A3KRRVHYFDDU59
# 13  B0071QVZI2     5.0  1421884800  A3KRRVHYFDDU59
# 14  B0071SYHIA     4.0  1444003200  A3KRRVHYFDDU59
# 15  B007BQBM0S     4.0  1447718400  A3KRRVHYFDDU59
# 16  B007ZYVGBQ     1.0  1445212800  A3KRRVHYFDDU59
# 17  B00816NYFI     5.0  1439942400  A3KRRVHYFDDU59
# 18  B004U42UR8     2.0  1421884800  A3KRRVHYFDDU59
# 19  B004Z0CN60     5.0  1473033600  A3KRRVHYFDDU59

# %%
review_5core.registerTempTable('review_5core')

query ="""
select distinct
    tb.*
from
    review_5core ta
join
    product_subset tb
on ta.item_id=tb.item_id
"""
product_5core = spark.sql(query)

# %%
product_5core.limit(5).toPandas()
# Out:
#       item_id brand                                           category  \
# 0  B0069J1Y2Y        [Clothing, Shoes & Jewelry, Women, Clothing, T...
# 1  B006MQR4QY        [Clothing, Shoes & Jewelry, Women, Clothing, C...
# 2  B006UCPQAQ        [Clothing, Shoes & Jewelry, Women, Clothing, D...
# 3  B0078LJ5KU        [Clothing, Shoes & Jewelry, Women, Clothing, T...
# 4  B007P5S2JY        [Clothing, Shoes & Jewelry, Women, Clothing, P...
#
#    category_levels                                        description  \
# 0                5                                               None
# 1                5                                               None
# 2                5                                               None
# 3                5                                               None
# 4                5  [Self fabric waistband with smooth interior el...
#
#              price                                              title  \
# 0  $21.59 - $26.99   PattyBoutik Women's Off Shoulder Long Sleeve Top
# 1                            AK Anne Klein Women's Ruffle Trench Coat
# 2                   HE02713BK10, Black, 8US, Ever Pretty Chic Lace...
# 3                   XOXO Juniors Smock Bottom Embellished Printed ...
# 4                                            PUMA Women's Velour Pant
#
#                                     url  \
# 0  https://www.amazon.com/dp/B0069J1Y2Y
# 1  https://www.amazon.com/dp/B006MQR4QY
# 2  https://www.amazon.com/dp/B006UCPQAQ
# 3  https://www.amazon.com/dp/B0078LJ5KU
# 4  https://www.amazon.com/dp/B007P5S2JY
#
#                                                image
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
# 3  https://images-na.ssl-images-amazon.com/images...
# 4  https://images-na.ssl-images-amazon.com/images...

# %%
product_5core.count()
# Out:
# 16883

# %%
'''
import mimetypes, urllib
from pyspark.sql.types import BooleanType
from pyspark.sql.functions import udf

def is_url_image(url):    
    mimetype,encoding = mimetypes.guess_type(url)
    return (mimetype and mimetype.startswith('image'))

def check_url(url):
    """Returns True if the url returns a response code between 200-300,
       otherwise return False.
    """
    try:
        headers = {
            "Range": "bytes=0-10",
            "User-Agent": "MyTestAgent",
            "Accept": "*/*"
        }

        req = urllib.request.Request(url, headers=headers)
        response = urllib.request.urlopen(req)
        print('response.code: ', response.code)
        return response.code in range(200, 209)
    except Exception as e:
        print('exception: ', e)
        return False

is_image_and_ready_udf = udf(lambda image: is_url_image(image) and check_url(image), BooleanType())


review_5core = review_5core.limit(10000)

product_5core = review_5core.select('item_id').distinct().join(product_5core, on='item_id', how='inner')
product_5core = product_5core.filter(is_image_and_ready_udf('image'))
product_5core.cache()

review_5core = product_5core.select('item_id').distinct().join(review_5core, on='item_id', how='inner')
review_5core.cache()

user_5core = review_5core.select('user_id').distinct().join(user_5core, on='user_id', how='inner')
user_5core.cache()
'''
# Out:
# '\nimport mimetypes, urllib\nfrom pyspark.sql.types import BooleanType\nfrom pyspark.sql.functions import udf\n\ndef is_url_image(url):    \n    mimetype,encoding = mimetypes.guess_type(url)\n    return (mimetype and mimetype.startswith(\'image\'))\n\ndef check_url(url):\n    """Returns True if the url returns a response code between 200-300,\n       otherwise return False.\n    """\n    try:\n        headers = {\n            "Range": "bytes=0-10",\n            "User-Agent": "MyTestAgent",\n            "Accept": "*/*"\n        }\n\n        req = urllib.request.Request(url, headers=headers)\n        response = urllib.request.urlopen(req)\n        print(\'response.code: \', response.code)\n        return response.code in range(200, 209)\n    except Exception as e:\n        print(\'exception: \', e)\n        return False\n\nis_image_and_ready_udf = udf(lambda image: is_url_image(image) and check_url(image), BooleanType())\n\n\nreview_5core = review_5core.limit(10000)\n\nproduct_5core = review_5core.select(\'item_id\').distinct().join(product_5core, on=\'item_id\', how=\'inner\')\nproduct_5core = product_5core.filter(is_image_and_ready_udf(\'image\'))\nproduct_5core.cache()\n\nreview_5core = product_5core.select(\'item_id\').distinct().join(review_5core, on=\'item_id\', how=\'inner\')\nreview_5core.cache()\n\nuser_5core = review_5core.select(\'user_id\').distinct().join(user_5core, on=\'user_id\', how=\'inner\')\nuser_5core.cache()\n'

# %%
# review_5core = review_5core.orderBy(F.rand()).limit(10000)
review_5core = review_5core.limit(10000)
review_5core.cache()

user_5core = review_5core.select('user_id').distinct().join(user_5core, on='user_id', how='inner')
user_5core.cache()

product_5core = review_5core.select('item_id').distinct().join(product_5core, on='item_id', how='inner')
product_5core.cache()
# Out:
# DataFrame[item_id: string, brand: string, category: array<string>, category_levels: bigint, description: array<string>, price: string, title: string, url: string, image: string]

# %%
from pyspark.sql.types import ArrayType

def concat_list_field(dataset, array_join_sep=u'\u0001'):
    array_cols = [f.name for f in dataset.schema.fields if isinstance(f.dataType, ArrayType)]
    for array_col in array_cols:
        dataset = dataset.withColumn(array_col, F.concat_ws(array_join_sep, F.col(array_col)))
    return dataset

review_5core = concat_list_field(review_5core)
user_5core = concat_list_field(user_5core)
product_5core = concat_list_field(product_5core)

# %%
print('review_5core: ', review_5core.count())
print('user_5core: ', user_5core.count())
print('product_5core: ', product_5core.count())
# Out:
# review_5core:  10000
# user_5core:  109
# [Stage 158:=================================================>   (187 + 2) / 200]
# product_5core:  2673

# %%
user_path = 's3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/amazon_fashion_user.small.parquet'
item_path = 's3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/amazon_fashion_item.small.parquet'
interaction_path = 's3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/amazon_fashion_interaction.small.parquet'

# %%
product_5core.limit(100).toPandas()
# Out:
#        item_id                                brand  \
# 0   B0069J1Y2Y
# 1   B008EYPQFI
# 2   B00B1ZNI1G
# 3   B00BHB82NS
# 4   B00BMHE5W4
# 5   B00ES83MGO
# 6   B00GUGX3WA                            Lindy Bop
# 7   B00H3RIRLM                               Hering
# 8   B00HGT81WW                        Dinamit Jeans
# 9   B00JGVAR34                       Glamour Empire
# 10  B00KXR6BCQ                                ETANG
# 11  B00V4GB1IE                           Urban CoCo
# 12  B00W6YKVVG                                 Hego
# 13  B00WB6FCE0
# 14  B0101114BG                          VIRGIN ONLY
# 15  B011DU3MU0                              Meaneor
# 16  B0177VIGCS                               Zeagoo
# 17  B01BV29AVA                    Boutique Republic
# 18  B01EWVLTYS                             GLOSTORY
# 19  B01FF36PI2                              FasiCat
# 20  B01GCTKZG6                              Meaneor
# 21  B008X0E6LS                            Allegra K
# 22  B00AZ818PS                              G2 Chic
# 23  B00CXQHXNQ                          Smart Range
# 24  B00DR4LVBI                            Hee grand
# 25  B00GN04FUC                           Affliction
# 26  B00J2D7QVW
# 27  B00LKCIDR4                              Pikulla
# 28  B00LVNV446                               L'eggs
# 29  B00S1UDCCO                        RK RUBY KARAT
# 30  B00SKOK40O
# 31  B00WM9E4AY                        Fashion Story
# 32  B011LAF6JM                            Lindy Bop
# 33  B01825EAP0                            R.Vivimos
# 34  B0185FVZJQ                              VamJump
# 35  B007NLXCJK
# 36  B008Y6EC88                    KD dance New York
# 37  B00D6QTRRC                              G2 Chic
# 38  B00GRQJQE2                              ELLAZHU
# 39  B00H5FXQRC
# 40  B00M7CFST2
# 41  B00NTBC25S
# 42  B00OUTZV9C
# 43  B00X1OM2T4
# 44  B0104HPNPU                         Sylvestidoso
# 45  B0143JASEG                              Hot Gal
# 46  B019SVXYOA                              Sunward
# 47  B01A0WIGSK                              Sheicon
# 48  B01FM5FN5Y                                Afibi
# 49  B001L9A4VY                                  LAT
# 50  B00KRCS4KY                                KRISP
# 51  B00RJZX02Y                Agatha Garcia Dresses
# 52  B00UHGF3SG
# 53  B00UN1GEG0
# 54  B00WVS7T26
# 55  B015H0NMTI                             DOINSHOP
# 56  B01762CKTS                  Xclusive Collection
# 57  B017CC5YZO                        RK RUBY KARAT
# 58  B01C6R1NIW                             LIREROJE
# 59  B01F8707FC
# 60  B01HHS79DS                              CA Mode
# 61  B001D69ASS
# 62  B009AFH1WQ
# 63  B00AODC4W0                              G2 Chic
# 64  B00DULOG1K
# 65  B00EPQMB1G
# 66  B00FDH2A9O                              vechell
# 67  B00GFL7BZU
# 68  B00GI1W3LE
# 69  B00GT5206C                      eVogues Apparel
# 70  B00MTFYUNW                          ACEFAST INC
# 71  B00SO2ZCFY                               Frumos
# 72  B00VAVW1PU               Hollywood Star Fashion
# 73  B00XTTUM4I                            Sheinside
# 74  B00YV50PUA                               CowCow
# 75  B0171H1ADK                              Meaneor
# 76  B01BA3GP5E                            Allegra K
# 77  B006QH6S3O
# 78  B00DXTYH7W                         2NE1 Apparel
# 79  B00GTJJ0CU                              ELLAZHU
# 80  B00GY4V3F2                          Crazy Girls
# 81  B00VWO4KRC
# 82  B00YRRJ5X0                               Zeagoo
# 83  B013CXBUGO                              Bozzolo
# 84  B014GFJ6J0                            URBANCLEO
# 85  B015XI8K3M  CHOiES record your inspired fashion
# 86  B019V875PY                      Babyonlinedress
# 87  B01B1DX2UY                               ANGVNS
# 88  B01DBWS53M                            Tueenhuge
# 89  B01FQNOVLO                            Kalvon-Fu
# 90  B003IG08RI
# 91  B00CWV8PK2
# 92  B00GNL6AEA                                 2LUV
# 93  B00O3HAR90                          Modern Kiwi
# 94  B00VG4ZVF8                            Lindy Bop
# 95  B016RUPRT0                                Myobe
# 96  B0171H8UO2                               Frumos
# 97  B01EEMDHSQ                              KMystic
# 98  B01G87QKMA                               VOGVOG
# 99  B007HYVK1U                                COREY
#
#                                              category  category_levels  \
# 0   Clothing, Shoes & JewelryWomenClothingTops,...                5
# 1      Clothing, Shoes & JewelryWomenClothingJeans                4
# 2   Clothing, Shoes & JewelryWomenClothingTops,...                5
# 3   Clothing, Shoes & JewelryWomenClothingTops,...                5
# 4      Clothing, Shoes & JewelryWomenClothingJeans                4
# 5   Clothing, Shoes & JewelryWomenClothingTops,...                5
# 6   Clothing, Shoes & JewelryWomenClothingDress...                5
# 7   Clothing, Shoes & JewelryWomenClothingTops,...                5
# 8      Clothing, Shoes & JewelryWomenClothingJeans                4
# 9   Clothing, Shoes & JewelryWomenClothingDress...                5
# 10  Clothing, Shoes & JewelryWomenClothingDress...                5
# 11  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 12  Clothing, Shoes & JewelryWomenClothingDress...                5
# 13  Clothing, Shoes & JewelryWomenClothingDress...                5
# 14  Clothing, Shoes & JewelryWomenClothingPants...                5
# 15  Clothing, Shoes & JewelryWomenClothingSweat...                5
# 16  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 17  Clothing, Shoes & JewelryWomenClothingSkirt...                5
# 18  Clothing, Shoes & JewelryWomenClothingShort...                5
# 19  Clothing, Shoes & JewelryWomenClothingDress...                5
# 20  Clothing, Shoes & JewelryWomenClothingFashi...                4
# 21  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 22  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 23  Clothing, Shoes & JewelryWomenClothingCoats...                5
# 24  Clothing, Shoes & JewelryWomenClothingCoats...                5
# 25  Clothing, Shoes & JewelryWomenClothingSweat...                5
# 26  Clothing, Shoes & JewelryWomenClothingPants...                5
# 27  Clothing, Shoes & JewelryWomenClothingDress...                5
# 28  Clothing, Shoes & JewelryWomenClothingSocks...                5
# 29  Clothing, Shoes & JewelryWomenClothingCoats...                5
# 30  Clothing, Shoes & JewelryWomenClothingShort...                5
# 31  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 32  Clothing, Shoes & JewelryWomenClothingDress...                5
# 33  Clothing, Shoes & JewelryWomenClothingCoats...                5
# 34  Clothing, Shoes & JewelryWomenClothingSweat...                5
# 35  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 36  Clothing, Shoes & JewelryWomenClothingSweat...                5
# 37  Clothing, Shoes & JewelryWomenClothingDress...                5
# 38  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 39  Clothing, Shoes & JewelryWomenClothingCoats...                5
# 40  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 41  Clothing, Shoes & JewelryWomenClothingPants...                5
# 42   Clothing, Shoes & JewelryWomenClothingDresses                4
# 43  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 44  Clothing, Shoes & JewelryWomenClothingDress...                5
# 45  Clothing, Shoes & JewelryWomenClothingSkirt...                5
# 46  Clothing, Shoes & JewelryWomenClothingSweat...                5
# 47  Clothing, Shoes & JewelryWomenClothingTops,...                4
# 48  Clothing, Shoes & JewelryWomenClothingSkirt...                5
# 49  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 50   Clothing, Shoes & JewelryWomenClothingDresses                4
# 51  Clothing, Shoes & JewelryWomenClothingDress...                5
# 52  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 53  Clothing, Shoes & JewelryWomenClothingSweat...                5
# 54  Clothing, Shoes & JewelryWomenClothingCoats...                5
# 55  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 56  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 57  Clothing, Shoes & JewelryWomenClothingSweat...                5
# 58  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 59  Clothing, Shoes & JewelryWomenClothingDress...                5
# 60  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 61  Clothing, Shoes & JewelryWomenClothingPants...                5
# 62  Clothing, Shoes & JewelryWomenClothingJeans...                5
# 63  Clothing, Shoes & JewelryWomenClothingDress...                5
# 64  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 65  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 66  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 67     Clothing, Shoes & JewelryWomenClothingJeans                4
# 68  Clothing, Shoes & JewelryWomenClothingDress...                5
# 69  Clothing, Shoes & JewelryWomenClothingFashi...                4
# 70  Clothing, Shoes & JewelryWomenClothingDress...                5
# 71  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 72  Clothing, Shoes & JewelryWomenClothingSweat...                5
# 73  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 74  Clothing, Shoes & JewelryWomenClothingDress...                5
# 75  Clothing, Shoes & JewelryWomenClothingDress...                5
# 76  Clothing, Shoes & JewelryWomenClothingTops,...                4
# 77  Clothing, Shoes & JewelryWomenClothingJeans...                5
# 78  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 79  Clothing, Shoes & JewelryWomenClothingCoats...                5
# 80  Clothing, Shoes & JewelryWomenClothingSweat...                5
# 81  Clothing, Shoes & JewelryWomenClothingDress...                5
# 82  Clothing, Shoes & JewelryWomenClothingDress...                5
# 83  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 84  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 85    Clothing, Shoes & JewelryWomenClothingSkirts                4
# 86  Clothing, Shoes & JewelryWomenClothingDress...                5
# 87   Clothing, Shoes & JewelryWomenClothingDresses                4
# 88  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 89  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 90  Clothing, Shoes & JewelryWomenClothingSocks...                5
# 91  Clothing, Shoes & JewelryWomenClothingTops,...                5
# 92  Clothing, Shoes & JewelryWomenClothingDress...                5
# 93  Clothing, Shoes & JewelryWomenClothingSweat...                5
# 94  Clothing, Shoes & JewelryWomenClothingDress...                5
# 95  Clothing, Shoes & JewelryWomenClothingSweat...                5
# 96  Clothing, Shoes & JewelryWomenClothingSkirt...                5
# 97  Clothing, Shoes & JewelryWomenClothingDress...                5
# 98  Clothing, Shoes & JewelryWomenClothingDress...                5
# 99  Clothing, Shoes & JewelryWomenClothingDress...                5
#
#                                           description             price  \
# 0                                                       $21.59 - $26.99
# 1   Look one size smaller in this Not Your Daughte...  $37.81 - $158.00
# 2   Women's embroidered short sleeve scoop neck bl...
# 3
# 4                                                       $27.99 - $40.00
# 5   PattyBoutik Sweetheart Cross-front V Neck Ruch...            $29.99
# 6   STYLE NAME:BRIGITTE A ELEGANT JERSEY PENCIL DR...
# 7   Spaghetti Strap Tank topNon adjustable strapsB...
# 8                                                        $9.99 - $14.99
# 9   Beautiful jersey cocktail / summer dress with ...    $9.72 - $24.23
# 10
# 11  Size chart  XS;Bust 33" --Sleeve 9.4" --Length...    $9.99 - $15.95
# 12
# 13  Versatile casual maxi dress features floral pr...   $12.99 - $21.99
# 14  There is nothing sexier and more flattering th...   $19.99 - $23.99
# 15  Measurements: 1. Use similar clothing to compa...   $12.99 - $18.99
# 16                                                       $4.49 - $24.49
# 17  Womens Maxi Skirts Collection of various print...
# 18  High quality fabrics, narrow cuts, and unique ...
# 19
# 20  Measurements:Please check your measurements to...
# 21
# 22  Solid sleeveless princess tank, ruched detaili...
# 23  A cool jacket indeed. Made from real soft lamb...           $182.58
# 24                                                      $33.46 - $59.99
# 25  Affliction Women Hooded Sweater Bell Long Slee...
# 26                                                       $9.95 - $22.95
# 27  Pikulla Vintage V-Neck Sleeveless Rainbow Dres...             $9.99
# 28  Micro toning action gently hugs legs, creating...   $11.99 - $14.00
# 29  These classic cropped long sleeve denim jean j...
# 30  Stylish, Classic, Preppy American style since ...   $44.95 - $44.99
# 31  "Fashion Story" is a trademarked and Amazon br...    $6.99 - $10.99
# 32  Unleash your inner pinup girl in this adorable...
# 33  Please Refer Standard Measurement Method:  * B...
# 34                                                               $25.99
# 35  Women's embroidered sleeveless blouse features...            $16.99
# 36  Presenting the KD dance New York Stretch Knit ...   $17.95 - $29.95
# 37  This classic dress featuring an elegant long m...
# 38  The brand ELLAZHU is owned by ELLAZHU's White ...
# 39                                                      $19.95 - $59.95
# 40                                                               $18.99
# 41  You've never had pants this bold and beautiful...   $17.99 - $22.99
# 42  Whoinshop Women Strapless Cute Bodycon Bandage...
# 43
# 44  Please note that :  - We recommend hand wash...   $15.99 - $29.99
# 45  High Fashion Trendy Design LAce Midi Skirt ...
# 46  Size details:   Int'l Size--US------Shoulder--...    $8.22 - $13.99
# 47                                                               $14.99
# 48                                                      $12.99 - $15.99
# 49  5.5 oz., 100% combed ringspun cotton jersey; t...
# 50  KRISP BASICS Knot Front Polka Dot Dress 6488,...   $14.00 - $18.00
# 51  Novelty Printed Mermaid Maxi Dress by Agatha G...
# 52                                                               $28.99
# 53  Doublju Soft Knit Dolman Sleeve Loose Fit Open...            $16.99
# 54                                                      $37.20 - $46.50
# 55                                                        $5.07 - $7.97
# 56  New Womens Plus Size Waterfall Hanky Hem Sequi...   $30.99 - $35.99
# 57  This basic ribbed long sleeve turtleneck shirt...
# 58  Classic Mock Neck Top Tee Long Sleeve Shirt Ot...   $14.99 - $17.99
# 59
# 60  Item Size: About Size S to XXL for Westerners ...            $10.49
# 61  Slim fit mid-rise stretch twill pant with boot...  $22.97 - $122.57
# 62  Our Luscious Curvy Skinny Jeans feature classi...
# 63  Casual loose silhouette, scoop neckline, short...
# 64  COLOR DISCLAIMER Due to monitor settings, moni...             $4.92
# 65
# 66
# 67  These luscious curvy boot cut jeans feature a ...   $24.99 - $32.50
# 68
# 69  Gorgeous plus size hoodie top is a perfect add...            $22.99
# 70  100% Brand New \n\nSize:S,M,L,XL\n\n1 inch = 2...
# 71  Made In USA. This women's tunic top from Frumo...
# 72  (Active) Lightweight and super flattering, thi...    $5.99 - $17.99
# 73  Sheinside is an International leading fashion...
# 74  CowCow Womens Cute Cats Dogs Animals Pet Pug P...   $18.99 - $20.99
# 75  Measurements: 1. Use similar clothing to compa...
# 76                                                      $12.99 - $20.99
# 77
# 78  This amazing seamless tube top is one size fit...             $6.95
# 79                                                               $27.95
# 80  Women's All over Skull Print Knitted Open Card...             $6.40
# 81                                                               $21.99
# 82  100% Brand New.  Material: Polyester  4 Colors...            $19.99
# 83  This Sexy And Comfortable Long Spaghetti Strap...    $4.97 - $14.99
# 84  URBANCLEO| Womens Side Slit Mini Dress Jersey ...
# 85                                                      $15.99 - $28.99
# 86  3/4 Sleeve 1940's style dresses V Neck Audrey ...
# 87                                                       $9.90 - $21.99
# 88  Attention:Size may be 2cm/1 inch inaccuracy du...
# 89  New style women t-shirt batwing sleeve comfort...             $7.99
# 90  Our sexy thigh-highs in a comfortable, soft Co...
# 91                                                               $15.99
# 92  Stand out this holiday season in our Chiffon B...
# 93  Adorned with thumbhole sleeve cuffs, this card...
# 94  STYLE NAME  VANESSA PINK RAINFORESTTHE ALLUR...
# 95                                                      $11.99 - $16.99
# 96  Frumos Womens Elastic Waist Maxi Skirts. Frumo...
# 97  This soft knit tube layering dress is perfect ...            $12.99
# 98  Material: 95% cotton + 5% spandex, breathable ...   $18.99 - $19.99
# 99
#
#                                                 title  \
# 0    PattyBoutik Women's Off Shoulder Long Sleeve Top
# 1         NYDJ Women's Petite Size Alina Legging Jean
# 2   Sakkas Embroidered 100% Cotton Scoop Neck Semi...
# 3   Democracy Women's Rayon Lawn Print 3/4 Sleeve ...
# 4   WallFlower Women's Juniors Basic Legendary Str...
# 5   PattyBoutik Women's Cross Front V Neck Ruched ...
# 6   Lindy Bop 'Brigitte' Vintage Office Secretary ...
# 7   Junior Women's Basic Wirefree Shelf Bra Tank T...
# 8     Dinamit Jeans Retro Flower Printed Skinny Pants
# 9   Glamour Empire Women's Knee Length Short Sleev...
# 10  ETANG Women's Chiffon Halter Strap Backless Be...
# 11  Women's Vogue Shoulder Off Wide Hem Design Top...
# 12  Hego Women's Quality PU Sexy Bodycon Club Part...
# 13  Simplicity Women's Bohemian Summer Floral Prin...
# 14        VIRGIN ONLY Women's Light Blue Tencel Pants
# 15  Meaneor Women's Long Sleeve Waterfall Asymmetr...
# 16  Zeagoo Women's Casual Floral Print Short Sleev...
# 17  Womens Maxi Skirts Collection of various print...
# 18  GLOSTORY Women's Causal Tassels Skinny Denim S...
# 19  FasiCat Fishnet Lingerie Sexy Mini Half Sleeve...
# 20  Meaneor Women's Low Cut V-Neck Short Sleeve Fl...
# 21  Allegra K Women Color Block Panel Batwing Loos...
# 22          G2 Chic Women's Princess Silk Ruched Tank
# 23  Smart Range Women's Speed Washed Retro Biker F...
# 24  Hee grand Women Winter Faux Fur Coat Winter Co...
# 25  Affliction Women Hooded Sweater Bell Long Slee...
# 26  Free to Live Women's Palazzo Gaucho Pants - Wi...
# 27  Pikulla V-Neck Sleeveless Women's Rainbow Gyps...
# 28  L'eggs Women's Energy 3 Pack All Sheer Panty Hose
# 29  RK RUBY KARAT Womens Classic Long Sleeve Denim...
# 30  Tommy Hilfiger Womens Twill Solid Khaki, Chino...
# 31  Fashion Story Women Casual T-Shirt Short Sleev...
# 32  Lindy Bop 'Bella' 1950's Inspired Nautical Str...
# 33  R.Vivimos Women Ruffled Asymmetric Long Velvet...
# 34  VamJump Women Open Front Thick Oversized Fleec...
# 35  Sakkas Batik Embroidered V-Neck Sleeveless Blouse
# 36  KD dance New York Stretch Knit Ballet Shrug De...
# 37  G2 Chic Women's Classic Sleeveless Elastic Wai...
# 38  ELLAZHU Women Baggy Skull&Stars Painting Long ...
# 39  Made By Johnny MBJ Womens Faux Leather Motorcy...
# 40  Sakkas Metallic Liquid Mock Neck Turtleneck Lo...
# 41  VIV Collection Women's Chevron Aztec Tribal Pa...
# 42  Whoinshop Women Strapless Cute Bodycon Bandage...
# 43  KOGMO Womens Short Sleeve Solid Basic Tunic To...
# 44  Sylvestidoso Fashion Women's A-Line Pleated Sl...
# 45  Hot Gal Women's Plus Size Lace Bodycon Pencil ...
# 46  Sunward New Spring Drape Front Kimono Cardigan...
# 47  Sheicon Women Short Sleeve Shift Dress Floral ...
# 48  Afibi Womens Chiffon Floral Elastic High Waist...
# 49        LAT Ladies Combed V-Neck Sleeveless T-Shirt
# 50  KRISP Womens Casual Party Cocktail Polka Dot K...
# 51  Agatha Garcia Women's Novelty Printed Mermaid ...
# 52  PattyBoutik Women's Drape Wrap Elastic Hem Tan...
# 53  Doublju Soft Knit Dolman Sleeve Loose Fit Open...
# 54  Made By Johnny MBJ Womens Military Anorak Safa...
# 55  DOINSHOP Women's Lantern Long Sleeve Round Nec...
# 56  New Womens Plus Size Waterfall Hanky Hem Sequi...
# 57  RK RUBY KARAT Womens Basic Ribbed Long Sleeve ...
# 58  LIREROJE Women's Mock Turtleneck Fullback Shap...
# 59  KOH KOH Womens Cap Short Sleeve Elegant Cockta...
# 60  CA Mode Women Office Work Plaids Shirt Checks ...
# 61  Dickies Women's Flat Front Stretch Twill Pant ...
# 62  WallFlower Juniors Luscious Curvy Classic Skin...
# 63           G2 Chic Women's Button Front Shirt Dress
# 64  Emmalise Women's Sexy Fashion Lace Bandeau Str...
# 65  Sexy Perforated Detail Seamless Bodycon Tube S...
# 66  Vechell Women's Sexy Leopard Chiffon Batwing S...
# 67     WallFlower Women's Luscious Curvy Bootcut Jean
# 68  Women's Party Casual Fitted Seamless Bodycon S...
# 69            eVogues Plus Size Angel Wing Hoodie Top
# 70  Women's Casual Long Sleeve Summer Cocktail Par...
# 71  Frumos Womens 3/4 Sleeve Tunic Top V-Neck T Shirt
# 72  Hollywood Star Fashion Women's Long Sleeves Cr...
# 73  Sheinside Women's Blue V Neck Epaulet Dip Hem ...
# 74  CowCow Womens Cute Cats Dogs Animals Pet Pug P...
# 75  Meaneor Women 1920s Beaded Fringe Scalloped Pe...
# 76  Women's Long Sleeves Scoop Neck Striped Chevro...
# 77                               Vigoss Crop Leg Jean
# 78  2NE1 Apparel Women's Basic Stretch Layer Seaml...
# 79  ELLAZHU Women Fledermaus Cropped Sleeve Lapel ...
# 80  Crazy Girls Women's Skull Print Knitted Open C...
# 81  TAM Ware Women Stylish Slim Fit Knit Sweater B...
# 82  Zeagoo Women's Novelty Jersey Night Club Cravi...
# 83  Bozzolo Women's Ladies Adjustable Spaghetti St...
# 84  URBANCLEO Womens Side Slit Casual Beach Mini T...
# 85  CHOiES record your inspired fashion Women's Wh...
# 86  Babyonlinedress 3/4 Sleeve 1940's Style Dresse...
# 87  ANGVNS Women's V Neck Sleeveless Cocktail Body...
# 88  Tueenhuge Women's Cut Out Cold Shoulder Lace T...
# 89  Kalvon-Fu Women's Round Neck Casual Loose Shor...
# 90  American Apparel Women Cotton Solid Thigh-High...
# 91  Doublju V-Neck Handkerchief Hem Long Tunic Shi...
# 92  2LUV Women's Sleeveless Chiffon Cocktail Dress...
# 93  Modern Kiwi Solid Knit Asymmetric Buttoned Thu...
# 94  Lindy Bop 'Vanessa' Stunning Vintage, 50's Ins...
# 95  Myobe Women's Kimonos Geometric Print Drape Bo...
# 96    Frumos Womens High Waisted Fold Over Maxi Skirt
# 97         KMystic Seamless Strapless Tube Slip Dress
# 98  VOGVOG Fedie Women Boatneck Sleeveless Vintage...
# 99            COREY Lynn Calter Women's Beverly Dress
#
#                                      url  \
# 0   https://www.amazon.com/dp/B0069J1Y2Y
# 1   https://www.amazon.com/dp/B008EYPQFI
# 2   https://www.amazon.com/dp/B00B1ZNI1G
# 3   https://www.amazon.com/dp/B00BHB82NS
# 4   https://www.amazon.com/dp/B00BMHE5W4
# 5   https://www.amazon.com/dp/B00ES83MGO
# 6   https://www.amazon.com/dp/B00GUGX3WA
# 7   https://www.amazon.com/dp/B00H3RIRLM
# 8   https://www.amazon.com/dp/B00HGT81WW
# 9   https://www.amazon.com/dp/B00JGVAR34
# 10  https://www.amazon.com/dp/B00KXR6BCQ
# 11  https://www.amazon.com/dp/B00V4GB1IE
# 12  https://www.amazon.com/dp/B00W6YKVVG
# 13  https://www.amazon.com/dp/B00WB6FCE0
# 14  https://www.amazon.com/dp/B0101114BG
# 15  https://www.amazon.com/dp/B011DU3MU0
# 16  https://www.amazon.com/dp/B0177VIGCS
# 17  https://www.amazon.com/dp/B01BV29AVA
# 18  https://www.amazon.com/dp/B01EWVLTYS
# 19  https://www.amazon.com/dp/B01FF36PI2
# 20  https://www.amazon.com/dp/B01GCTKZG6
# 21  https://www.amazon.com/dp/B008X0E6LS
# 22  https://www.amazon.com/dp/B00AZ818PS
# 23  https://www.amazon.com/dp/B00CXQHXNQ
# 24  https://www.amazon.com/dp/B00DR4LVBI
# 25  https://www.amazon.com/dp/B00GN04FUC
# 26  https://www.amazon.com/dp/B00J2D7QVW
# 27  https://www.amazon.com/dp/B00LKCIDR4
# 28  https://www.amazon.com/dp/B00LVNV446
# 29  https://www.amazon.com/dp/B00S1UDCCO
# 30  https://www.amazon.com/dp/B00SKOK40O
# 31  https://www.amazon.com/dp/B00WM9E4AY
# 32  https://www.amazon.com/dp/B011LAF6JM
# 33  https://www.amazon.com/dp/B01825EAP0
# 34  https://www.amazon.com/dp/B0185FVZJQ
# 35  https://www.amazon.com/dp/B007NLXCJK
# 36  https://www.amazon.com/dp/B008Y6EC88
# 37  https://www.amazon.com/dp/B00D6QTRRC
# 38  https://www.amazon.com/dp/B00GRQJQE2
# 39  https://www.amazon.com/dp/B00H5FXQRC
# 40  https://www.amazon.com/dp/B00M7CFST2
# 41  https://www.amazon.com/dp/B00NTBC25S
# 42  https://www.amazon.com/dp/B00OUTZV9C
# 43  https://www.amazon.com/dp/B00X1OM2T4
# 44  https://www.amazon.com/dp/B0104HPNPU
# 45  https://www.amazon.com/dp/B0143JASEG
# 46  https://www.amazon.com/dp/B019SVXYOA
# 47  https://www.amazon.com/dp/B01A0WIGSK
# 48  https://www.amazon.com/dp/B01FM5FN5Y
# 49  https://www.amazon.com/dp/B001L9A4VY
# 50  https://www.amazon.com/dp/B00KRCS4KY
# 51  https://www.amazon.com/dp/B00RJZX02Y
# 52  https://www.amazon.com/dp/B00UHGF3SG
# 53  https://www.amazon.com/dp/B00UN1GEG0
# 54  https://www.amazon.com/dp/B00WVS7T26
# 55  https://www.amazon.com/dp/B015H0NMTI
# 56  https://www.amazon.com/dp/B01762CKTS
# 57  https://www.amazon.com/dp/B017CC5YZO
# 58  https://www.amazon.com/dp/B01C6R1NIW
# 59  https://www.amazon.com/dp/B01F8707FC
# 60  https://www.amazon.com/dp/B01HHS79DS
# 61  https://www.amazon.com/dp/B001D69ASS
# 62  https://www.amazon.com/dp/B009AFH1WQ
# 63  https://www.amazon.com/dp/B00AODC4W0
# 64  https://www.amazon.com/dp/B00DULOG1K
# 65  https://www.amazon.com/dp/B00EPQMB1G
# 66  https://www.amazon.com/dp/B00FDH2A9O
# 67  https://www.amazon.com/dp/B00GFL7BZU
# 68  https://www.amazon.com/dp/B00GI1W3LE
# 69  https://www.amazon.com/dp/B00GT5206C
# 70  https://www.amazon.com/dp/B00MTFYUNW
# 71  https://www.amazon.com/dp/B00SO2ZCFY
# 72  https://www.amazon.com/dp/B00VAVW1PU
# 73  https://www.amazon.com/dp/B00XTTUM4I
# 74  https://www.amazon.com/dp/B00YV50PUA
# 75  https://www.amazon.com/dp/B0171H1ADK
# 76  https://www.amazon.com/dp/B01BA3GP5E
# 77  https://www.amazon.com/dp/B006QH6S3O
# 78  https://www.amazon.com/dp/B00DXTYH7W
# 79  https://www.amazon.com/dp/B00GTJJ0CU
# 80  https://www.amazon.com/dp/B00GY4V3F2
# 81  https://www.amazon.com/dp/B00VWO4KRC
# 82  https://www.amazon.com/dp/B00YRRJ5X0
# 83  https://www.amazon.com/dp/B013CXBUGO
# 84  https://www.amazon.com/dp/B014GFJ6J0
# 85  https://www.amazon.com/dp/B015XI8K3M
# 86  https://www.amazon.com/dp/B019V875PY
# 87  https://www.amazon.com/dp/B01B1DX2UY
# 88  https://www.amazon.com/dp/B01DBWS53M
# 89  https://www.amazon.com/dp/B01FQNOVLO
# 90  https://www.amazon.com/dp/B003IG08RI
# 91  https://www.amazon.com/dp/B00CWV8PK2
# 92  https://www.amazon.com/dp/B00GNL6AEA
# 93  https://www.amazon.com/dp/B00O3HAR90
# 94  https://www.amazon.com/dp/B00VG4ZVF8
# 95  https://www.amazon.com/dp/B016RUPRT0
# 96  https://www.amazon.com/dp/B0171H8UO2
# 97  https://www.amazon.com/dp/B01EEMDHSQ
# 98  https://www.amazon.com/dp/B01G87QKMA
# 99  https://www.amazon.com/dp/B007HYVK1U
#
#                                                 image
# 0   https://images-na.ssl-images-amazon.com/images...
# 1   https://images-na.ssl-images-amazon.com/images...
# 2   https://images-na.ssl-images-amazon.com/images...
# 3   https://images-na.ssl-images-amazon.com/images...
# 4   https://images-na.ssl-images-amazon.com/images...
# 5   https://images-na.ssl-images-amazon.com/images...
# 6   https://images-na.ssl-images-amazon.com/images...
# 7   https://images-na.ssl-images-amazon.com/images...
# 8   https://images-na.ssl-images-amazon.com/images...
# 9   https://images-na.ssl-images-amazon.com/images...
# 10  https://images-na.ssl-images-amazon.com/images...
# 11  https://images-na.ssl-images-amazon.com/images...
# 12  https://images-na.ssl-images-amazon.com/images...
# 13  https://images-na.ssl-images-amazon.com/images...
# 14  https://images-na.ssl-images-amazon.com/images...
# 15  https://images-na.ssl-images-amazon.com/images...
# 16  https://images-na.ssl-images-amazon.com/images...
# 17  https://images-na.ssl-images-amazon.com/images...
# 18  https://images-na.ssl-images-amazon.com/images...
# 19  https://images-na.ssl-images-amazon.com/images...
# 20  https://images-na.ssl-images-amazon.com/images...
# 21  https://images-na.ssl-images-amazon.com/images...
# 22  https://images-na.ssl-images-amazon.com/images...
# 23  https://images-na.ssl-images-amazon.com/images...
# 24  https://images-na.ssl-images-amazon.com/images...
# 25  https://images-na.ssl-images-amazon.com/images...
# 26  https://images-na.ssl-images-amazon.com/images...
# 27  https://images-na.ssl-images-amazon.com/images...
# 28  https://images-na.ssl-images-amazon.com/images...
# 29  https://images-na.ssl-images-amazon.com/images...
# 30  https://images-na.ssl-images-amazon.com/images...
# 31  https://images-na.ssl-images-amazon.com/images...
# 32  https://images-na.ssl-images-amazon.com/images...
# 33  https://images-na.ssl-images-amazon.com/images...
# 34  https://images-na.ssl-images-amazon.com/images...
# 35  https://images-na.ssl-images-amazon.com/images...
# 36  https://images-na.ssl-images-amazon.com/images...
# 37  https://images-na.ssl-images-amazon.com/images...
# 38  https://images-na.ssl-images-amazon.com/images...
# 39  https://images-na.ssl-images-amazon.com/images...
# 40  https://images-na.ssl-images-amazon.com/images...
# 41  https://images-na.ssl-images-amazon.com/images...
# 42  https://images-na.ssl-images-amazon.com/images...
# 43  https://images-na.ssl-images-amazon.com/images...
# 44  https://images-na.ssl-images-amazon.com/images...
# 45  https://images-na.ssl-images-amazon.com/images...
# 46  https://images-na.ssl-images-amazon.com/images...
# 47  https://images-na.ssl-images-amazon.com/images...
# 48  https://images-na.ssl-images-amazon.com/images...
# 49  https://images-na.ssl-images-amazon.com/images...
# 50  https://images-na.ssl-images-amazon.com/images...
# 51  https://images-na.ssl-images-amazon.com/images...
# 52  https://images-na.ssl-images-amazon.com/images...
# 53  https://images-na.ssl-images-amazon.com/images...
# 54  https://images-na.ssl-images-amazon.com/images...
# 55  https://images-na.ssl-images-amazon.com/images...
# 56  https://images-na.ssl-images-amazon.com/images...
# 57  https://images-na.ssl-images-amazon.com/images...
# 58  https://images-na.ssl-images-amazon.com/images...
# 59  https://images-na.ssl-images-amazon.com/images...
# 60  https://images-na.ssl-images-amazon.com/images...
# 61  https://images-na.ssl-images-amazon.com/images...
# 62  https://images-na.ssl-images-amazon.com/images...
# 63  https://images-na.ssl-images-amazon.com/images...
# 64  https://images-na.ssl-images-amazon.com/images...
# 65  https://images-na.ssl-images-amazon.com/images...
# 66  https://images-na.ssl-images-amazon.com/images...
# 67  https://images-na.ssl-images-amazon.com/images...
# 68  https://images-na.ssl-images-amazon.com/images...
# 69  https://images-na.ssl-images-amazon.com/images...
# 70  https://images-na.ssl-images-amazon.com/images...
# 71  https://images-na.ssl-images-amazon.com/images...
# 72  https://images-na.ssl-images-amazon.com/images...
# 73  https://images-na.ssl-images-amazon.com/images...
# 74  https://images-na.ssl-images-amazon.com/images...
# 75  https://images-na.ssl-images-amazon.com/images...
# 76  https://images-na.ssl-images-amazon.com/images...
# 77  https://images-na.ssl-images-amazon.com/images...
# 78  https://images-na.ssl-images-amazon.com/images...
# 79  https://images-na.ssl-images-amazon.com/images...
# 80  https://images-na.ssl-images-amazon.com/images...
# 81  https://images-na.ssl-images-amazon.com/images...
# 82  https://images-na.ssl-images-amazon.com/images...
# 83  https://images-na.ssl-images-amazon.com/images...
# 84  https://images-na.ssl-images-amazon.com/images...
# 85  https://images-na.ssl-images-amazon.com/images...
# 86  https://images-na.ssl-images-amazon.com/images...
# 87  https://images-na.ssl-images-amazon.com/images...
# 88  https://images-na.ssl-images-amazon.com/images...
# 89  https://images-na.ssl-images-amazon.com/images...
# 90  https://images-na.ssl-images-amazon.com/images...
# 91  https://images-na.ssl-images-amazon.com/images...
# 92  https://images-na.ssl-images-amazon.com/images...
# 93  https://images-na.ssl-images-amazon.com/images...
# 94  https://images-na.ssl-images-amazon.com/images...
# 95  https://images-na.ssl-images-amazon.com/images...
# 96  https://images-na.ssl-images-amazon.com/images...
# 97  https://images-na.ssl-images-amazon.com/images...
# 98  https://images-na.ssl-images-amazon.com/images...
# 99  https://images-na.ssl-images-amazon.com/images...

# %%
# user_5core.repartition(1).write.option("header", True).csv(user_path, mode='overwrite')
user_5core.repartition(1).write.parquet(user_path, mode='overwrite')

# %%
# product_5core.repartition(1).write.option("header", True).csv(item_path, mode='overwrite')
product_5core.repartition(1).write.parquet(item_path, mode='overwrite')

# %%
# review_5core.repartition(1).write.option("header", True).csv(interaction_path, mode='overwrite')
review_5core.repartition(1).write.parquet(interaction_path, mode='overwrite')

# %%
# !aws s3 ls s3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/
# Out:
#                            PRE amazon_fashion_interaction.csv/
#                            PRE amazon_fashion_interaction.parquet/
#                            PRE amazon_fashion_interaction.small.parquet/
#                            PRE amazon_fashion_item.csv/
#                            PRE amazon_fashion_item.parquet/
#                            PRE amazon_fashion_item.small.parquet/
#                            PRE amazon_fashion_user.csv/
#                            PRE amazon_fashion_user.parquet/
#                            PRE amazon_fashion_user.small.parquet/
# 2022-09-08 14:11:37 3247339254 amazon_fashion_product.json
# 2022-09-08 14:13:55 3059298908 amazon_fashion_review.json

# %%
stop_spark(spark)
# Out:
# Debug -- spark stop
# 22/10/09 13:51:48 WARN ExecutorPodsWatchSnapshotSource: Kubernetes client has been closed (this is expected if the application is shutting down.)
