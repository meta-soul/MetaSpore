# %%
# !aws s3 ls s3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/
# Out:
#                            PRE amazon_fashion_interaction.parquet/
#                            PRE amazon_fashion_item.parquet/
#                            PRE amazon_fashion_user.parquet/
# 2022-09-08 14:11:37 3247339254 amazon_fashion_product.json
# 2022-09-08 14:13:55 3059298908 amazon_fashion_review.json

# %%
import os
import subprocess
import yaml
import argparse
import sys 
import importlib
import metaspore as ms
import pandas as pd
import warnings

warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
def init_spark(local, app_name, batch_size, worker_count, server_count,
               worker_memory, server_memory, coordinator_memory, **kwargs):
    subprocess.run(['zip', '-r', os.getcwd() + '/python.zip', 'python'], cwd='../../../')
    spark_confs={
        "spark.kubernetes.namespace":"sunkai",
        "spark.network.timeout":"500",
        "spark.submit.pyFiles":"python.zip",
        "spark.ui.showConsoleProgress": "true",
        "spark.kubernetes.executor.deleteOnTermination":"true",
    }
    spark = ms.spark.get_session(
        local=local,
        app_name=app_name,
        batch_size=batch_size,
        worker_count=worker_count,
        server_count=server_count,
        worker_memory=worker_memory,
        server_memory=server_memory,
        coordinator_memory=coordinator_memory,
        spark_confs=spark_confs)
    sc = spark.sparkContext
    print('Debug -- spark init')
    print('Debug -- version:', sc.version)   
    print('Debug -- applicaitonId:', sc.applicationId)
    print('Debug -- uiWebUrl:', sc.uiWebUrl)
    return spark

def stop_spark(spark):
    print('Debug -- spark stop')
    spark.sparkContext.stop()

def read_dataset(spark, dataset_path):
    dataset = spark.read.json(dataset_path)
    print('Debug -- item dataset count:', dataset.count())
    return dataset

# %%
# spark
params = {}
params['local'] = False
params['app_name'] = 'Amazon Fashion Dataset'
params['batch_size'] = 512
params['worker_count'] = 4
params['worker_cpu'] = 4
params['server_count'] = 4
params['server_cpu'] = 4
params['worker_memory'] = '6G'
params['server_memory'] = '6G'
params['coordinator_memory'] = '2G'

# input files
product_path = 's3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/amazon_fashion_product.json'
review_path = 's3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/amazon_fashion_review.json'

# output files
user_path = 's3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/amazon_fashion_user.parquet'
item_path = 's3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/amazon_fashion_item.parquet'
interaction_path = 's3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/amazon_fashion_interaction.parquet'

spark = init_spark(**params)
# Out:
# updating: python/ (stored 0%)
# updating: python/scripts/ (stored 0%)
# updating: python/scripts/consul/ (stored 0%)
# updating: python/scripts/consul/create_consul_watch.sh (deflated 17%)
# updating: python/scripts/consul/consul_watch_load.py (deflated 72%)
# updating: python/scripts/consul/build.sh (deflated 30%)
# updating: python/scripts/consul/Dockerfile (deflated 44%)
# updating: python/scripts/preprocessing/ (stored 0%)
# updating: python/scripts/preprocessing/preprocessor_service.py (deflated 69%)
# updating: python/scripts/preprocessing/example_preprocessor.py (deflated 54%)
# updating: python/scripts/preprocessing/example_requirements.txt (stored 0%)
# updating: python/scripts/preprocessing/test_example_preprocessor.py (deflated 51%)
# updating: python/tests/ (stored 0%)
# updating: python/tests/sparse_two_tower_export_demo.py (deflated 73%)
# updating: python/tests/sparse_wdl_grpc_test.py (deflated 52%)
# updating: python/tests/dense_xgboost_grpc_test.py (deflated 44%)
# updating: python/tests/mnist_mlp.py (deflated 59%)
# updating: python/tests/dense_xgboost.py (deflated 49%)
# updating: python/tests/verify_java_tensor_serde.py (deflated 42%)
# updating: python/tests/sparse_wdl_export_test.py (deflated 66%)
# updating: python/tests/two_tower_retrieval_milvus.py (deflated 81%)
# updating: python/tests/sparse_wdl_export_demo.py (deflated 64%)
# updating: python/tests/mnist_mlp_eval.py (deflated 57%)
# updating: python/tests/embedding_bag_export.py (deflated 61%)
# updating: python/tests/requirements.txt (deflated 24%)
# updating: python/tests/sparse_mlp_export_demo.py (deflated 64%)
# updating: python/algos/ (stored 0%)
# updating: python/algos/layers.py (deflated 79%)
# updating: python/algos/ffm_net.py (deflated 71%)
# updating: python/algos/deepfm_net.py (deflated 69%)
# updating: python/algos/autoint_net.py (deflated 70%)
# updating: python/algos/dcn_net.py (deflated 69%)
# updating: python/algos/pnn_net.py (deflated 70%)
# updating: python/algos/fwfm_net.py (deflated 69%)
# updating: python/algos/widedeep_net.py (deflated 68%)
# updating: python/algos/feature/ (stored 0%)
# updating: python/algos/feature/woe_encoder.py (deflated 64%)
# updating: python/algos/feature/__init__.py (deflated 37%)
# updating: python/algos/item_cf_retrieval.py (deflated 77%)
# updating: python/algos/multitask/ (stored 0%)
# updating: python/algos/multitask/mmoe/ (stored 0%)
# updating: python/algos/multitask/mmoe/mmoe_agent.py (deflated 70%)
# updating: python/algos/multitask/mmoe/mmoe_net.py (deflated 75%)
# updating: python/algos/multitask/esmm/ (stored 0%)
# updating: python/algos/multitask/esmm/esmm_net.py (deflated 69%)
# updating: python/algos/multitask/esmm/esmm_agent.py (deflated 74%)
# updating: python/algos/multitask/__init__.py (deflated 43%)
# updating: python/algos/sequential/ (stored 0%)
# updating: python/algos/sequential/dien/ (stored 0%)
# updating: python/algos/sequential/dien/dien_agent.py (deflated 61%)
# updating: python/algos/sequential/dien/dien_net.py (deflated 79%)
# updating: python/algos/sequential/din/ (stored 0%)
# updating: python/algos/sequential/din/din_net.py (deflated 76%)
# updating: python/algos/sequential/__init__.py (deflated 41%)
# updating: python/algos/dcn_v2_net.py (deflated 75%)
# updating: python/algos/twotower/ (stored 0%)
# updating: python/algos/twotower/dssm/ (stored 0%)
# updating: python/algos/twotower/dssm/dssm_agent.py (deflated 72%)
# updating: python/algos/twotower/dssm/dssm_net.py (deflated 78%)
# updating: python/algos/twotower/dssm/__init__.py (deflated 41%)
# updating: python/algos/twotower/retrieval_metric.py (deflated 68%)
# updating: python/algos/twotower/simplex/ (stored 0%)
# updating: python/algos/twotower/simplex/simplex_net.py (deflated 71%)
# updating: python/algos/twotower/simplex/simplex_agent.py (deflated 64%)
# updating: python/algos/twotower/simplex/__init__.py (deflated 39%)
# updating: python/algos/twotower/two_tower_retrieval.py (deflated 81%)
# updating: python/algos/twotower/__init__.py (deflated 40%)
# updating: python/algos/xdeepfm_net.py (deflated 71%)
# updating: python/algos/tuner/ (stored 0%)
# updating: python/algos/tuner/base_tuner.py (deflated 70%)
# updating: python/algos/__init__.py (deflated 38%)
# updating: python/metaspore/ (stored 0%)
# updating: python/metaspore/network_utils.py (deflated 52%)
# updating: python/metaspore/stack_trace_utils.py (deflated 43%)
# updating: python/metaspore/agent.py (deflated 77%)
# updating: python/metaspore/shell_utils.py (deflated 65%)
# updating: python/metaspore/estimator.py (deflated 85%)
# updating: python/metaspore/url_utils.py (deflated 51%)
# updating: python/metaspore/embedding.py (deflated 81%)
# updating: python/metaspore/metric.py (deflated 78%)
# updating: python/metaspore/file_utils.py (deflated 69%)
# updating: python/metaspore/swing_retrieval.py (deflated 79%)
# updating: python/metaspore/two_tower_ranking.py (deflated 80%)
# updating: python/metaspore/name_utils.py (deflated 37%)
# updating: python/metaspore/input.py (deflated 59%)
# updating: python/metaspore/updater.py (deflated 81%)
# updating: python/metaspore/distributed_trainer.py (deflated 76%)
# updating: python/metaspore/spark.py (deflated 71%)
# updating: python/metaspore/output.py (deflated 56%)
# updating: python/metaspore/initializer.py (deflated 76%)
# updating: python/metaspore/feature_group.py (deflated 58%)
# updating: python/metaspore/job_utils.py (deflated 47%)
# updating: python/metaspore/model.py (deflated 81%)
# updating: python/metaspore/two_tower_retrieval.py (deflated 83%)
# updating: python/metaspore/loss_utils.py (deflated 40%)
# updating: python/metaspore/distributed_tensor.py (deflated 80%)
# updating: python/metaspore/demo.py (deflated 54%)
# updating: python/metaspore/schema_utils.py (deflated 70%)
# updating: python/metaspore/patching_pickle.py (deflated 72%)
# updating: python/metaspore/cast.py (deflated 60%)
# updating: python/metaspore/__init__.py (deflated 68%)
# updating: python/metaspore/compat/ (stored 0%)
# updating: python/metaspore/compat/ps/ (stored 0%)
# updating: python/metaspore/compat/ps/__init__.py (deflated 66%)
# updating: python/metaspore/compat/__init__.py (deflated 52%)
# updating: python/metaspore/s3_utils.py (deflated 73%)
# updating: python/metaspore/experiment.py (deflated 76%)
# updating: python/metaspore/ps_launcher.py (deflated 68%)
# updating: python/metaspore/nn/ (stored 0%)
# updating: python/metaspore/nn/fm.py (deflated 47%)
# updating: python/metaspore/nn/wide_and_deep.py (deflated 75%)
# updating: python/metaspore/nn/deep_fm.py (deflated 70%)
# updating: python/metaspore/nn/normalization.py (deflated 61%)
# updating: python/metaspore/nn/__init__.py (deflated 41%)
# updating: python/ps/ (stored 0%)
# updating: python/ps/job.py (deflated 81%)
# updating: python/ps/__init__.py (deflated 42%)
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/lib/python3.8/dist-packages/pyspark/jars/spark-unsafe_2.12-3.1.2.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 22/09/08 19:44:50 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Debug -- spark init
# Debug -- version: 3.1.2
# Debug -- applicaitonId: spark-application-1662637491977
# Debug -- uiWebUrl: http://172.16.0.154:4040

# %%
product_dataset = read_dataset(spark, product_path)
# Out:
# [Stage 1:====================================================>    (23 + 2) / 25]
# Debug -- item dataset count: 2685059

# %%
product_dataset
# Out:
# DataFrame[brand: string, category: array<string>, category_levels: bigint, description: array<string>, image: string, item_id: string, price: string, title: string, url: string]

# %%
product_dataset.limit(20).toPandas()
# Out:
#                brand                                           category  \
# 0            Vintage  [Clothing, Shoes & Jewelry, Men, Uniforms, Wor...
# 1                     [Clothing, Shoes & Jewelry, Men, Uniforms, Wor...
# 2         PearlsOnly  [Clothing, Shoes & Jewelry, Women, Jewelry, Ri...
# 3          Wild Syde  [Clothing, Shoes & Jewelry, Men, Uniforms, Wor...
# 4   Government Issue  [Clothing, Shoes & Jewelry, Women, Uniforms, W...
# 5          Wild Syde  [Clothing, Shoes & Jewelry, Novelty & More, Cl...
# 6         PearlsOnly  [Clothing, Shoes & Jewelry, Women, Jewelry, Ri...
# 7          Wild Syde  [Clothing, Shoes & Jewelry, Men, Uniforms, Wor...
# 8          Wild Syde  [Clothing, Shoes & Jewelry, Men, Uniforms, Wor...
# 9         PearlsOnly  [Clothing, Shoes & Jewelry, Women, Jewelry, Ri...
# 10         Wild Syde  [Clothing, Shoes & Jewelry, Uniforms, Work & S...
# 11         Wild Syde  [Clothing, Shoes & Jewelry, Men, Uniforms, Wor...
# 12         Wild Syde  [Clothing, Shoes & Jewelry, Men, Uniforms, Wor...
# 13         Wild Syde  [Clothing, Shoes & Jewelry, Men, Uniforms, Wor...
# 14            Rothco  [Clothing, Shoes & Jewelry, Uniforms, Work & S...
# 15         Wild Syde  [Clothing, Shoes & Jewelry, Men, Uniforms, Wor...
# 16            Rothco  [Clothing, Shoes & Jewelry, Men, Uniforms, Wor...
# 17        PearlsOnly  [Clothing, Shoes & Jewelry, Women, Jewelry, Ri...
# 18         Wild Syde  [Clothing, Shoes & Jewelry, Men, Uniforms, Wor...
# 19        PearlsOnly  [Clothing, Shoes & Jewelry, Women, Jewelry, Ri...
#
#     category_levels                                        description image  \
# 0                 5                                               None
# 1                 5                                               None
# 2                 5                                               None
# 3                 5                                               None
# 4                 5  [This scarf is made from 100 Percent Soft Wool...
# 5                 5  [Supreme low profile military insignia cap. co...
# 6                 5                                               None
# 7                 5  [A Perfect Fashionable Attire, Built Durably T...
# 8                 5  [DRAWSTRING BOTTOMS, REINFORCED SEAT & KNEES, ...
# 9                 5                                               None
# 10                5                                               None
# 11                5                                               None
# 12                5  [Army Logo Sweatpants Physical Training Army S...
# 13                5                                               None
# 14                5  [Detachable & adjustable shoulder strap, Color...
# 15                5                                               None
# 16                5                                               None
# 17                5                                               None
# 18                5                                               None
# 19                5                                               None
#
#        item_id            price  \
# 0   B001L51GRO            $8.88
# 1   B001L52YW0           $13.99
# 2   B001L53NQ6           $85.00
# 3   B001L51C78           $26.99
# 4   B001L51C9G           $11.69
# 5   B001L4ZBFI
# 6   B001L53O3I           $85.00
# 7   B001L536UO           $10.99
# 8   B001L4ZB4Y           $39.99
# 9   B001L53OB0           $85.00
# 10  B001L52ZUG           $22.99
# 11  B001L54YKK   $9.99 - $10.99
# 12  B001L54ZOU           $27.99
# 13  B001L4ZBMG           $33.29
# 14  B001L551KW           $19.99
# 15  B001L55QB6  $50.99 - $55.99
# 16  B001L534H4            $7.86
# 17  B001L56N0Y           $85.00
# 18  B001L52YRK            $9.99
# 19  B001L53O74           $85.00
#
#                                                 title  \
# 0   4518 Vintage Olive Drab w/ Red Star Fatigue Ca...
# 1   var aPageStart = (new Date()).getTime();\nvar ...
# 2   Chantel Black 9-10mm AA Quality Freshwater 925...
# 3           Military Style Mini Alice Pack Black Pack
# 4   var aPageStart = (new Date()).getTime();\nvar ...
# 5                    9266 US Marine Corps Veteran Cap
# 6   Fiona Lavender 9-10mm AA Quality Freshwater 92...
# 7   Camouflage Caps ACU Digital Camo Fatigue Cap XLRG
# 8   Camouflage Pants City Camo Vintage Paratrooper...
# 9   Sadie Black 9-10mm AA Quality Freshwater 925 S...
# 10  Army Logo Sweatpants Physical Training Army Sw...
# 11      Kids Army T-Shirts Olive Drab Army Logo Shirt
# 12  Army Logo Sweatpants Physical Training Army Sw...
# 13  var aPageStart = (new Date()).getTime();\nvar ...
# 14           Shoulder Bag 24" Canvas Shoulder Bag BLK
# 15  Camouflage Cargo Pants Tiger Stripe Camo Vinta...
# 16                         Olive Drab BDU Belt - 54''
# 17  Fiona White 9-10mm AA Quality Freshwater 925 S...
# 18      Kids Army T-Shirts Olive Drab Army Logo Shirt
# 19  Fiona Black 9-10mm AA Quality Freshwater 925 S...
#
#                                      url
# 0   https://www.amazon.com/dp/B001L51GRO
# 1   https://www.amazon.com/dp/B001L52YW0
# 2   https://www.amazon.com/dp/B001L53NQ6
# 3   https://www.amazon.com/dp/B001L51C78
# 4   https://www.amazon.com/dp/B001L51C9G
# 5   https://www.amazon.com/dp/B001L4ZBFI
# 6   https://www.amazon.com/dp/B001L53O3I
# 7   https://www.amazon.com/dp/B001L536UO
# 8   https://www.amazon.com/dp/B001L4ZB4Y
# 9   https://www.amazon.com/dp/B001L53OB0
# 10  https://www.amazon.com/dp/B001L52ZUG
# 11  https://www.amazon.com/dp/B001L54YKK
# 12  https://www.amazon.com/dp/B001L54ZOU
# 13  https://www.amazon.com/dp/B001L4ZBMG
# 14  https://www.amazon.com/dp/B001L551KW
# 15  https://www.amazon.com/dp/B001L55QB6
# 16  https://www.amazon.com/dp/B001L534H4
# 17  https://www.amazon.com/dp/B001L56N0Y
# 18  https://www.amazon.com/dp/B001L52YRK
# 19  https://www.amazon.com/dp/B001L53O74

# %%
review_dataset = read_dataset(spark, review_path)
# Out:
# [Stage 6:======================================================>  (22 + 1) / 23]
# Debug -- item dataset count: 32292099

# %%
import pyspark.sql.functions as F
product_subset = product_dataset.where(F.array_contains(F.col("category"), 'Clothing') & 
                                       F.array_contains(F.col('category'), 'Women'))

# %%
product_subset.limit(10).toPandas()
# Out:
#               brand                                           category  \
# 0  Government Issue  [Clothing, Shoes & Jewelry, Women, Uniforms, W...
# 1   Flip Flop Socks       [Clothing, Shoes & Jewelry, Women, Clothing]
# 2                    [Clothing, Shoes & Jewelry, Women, Clothing, T...
# 3                    [Clothing, Shoes & Jewelry, Women, Clothing, T...
# 4                    [Clothing, Shoes & Jewelry, Women, Clothing, S...
# 5                    [Clothing, Shoes & Jewelry, Women, Clothing, P...
# 6           SockGuy  [Clothing, Shoes & Jewelry, Novelty & More, Cl...
# 7                    [Clothing, Shoes & Jewelry, Women, Clothing, F...
# 8       A&E Designs  [Clothing, Shoes & Jewelry, Novelty & More, Cl...
# 9           Unknown  [Clothing, Shoes & Jewelry, Novelty & More, Cl...
#
#    category_levels                                        description image  \
# 0                5  [This scarf is made from 100 Percent Soft Wool...
# 1                3                                               None
# 2                5       [IZOD is premium clothing for everyday wear]
# 3                5       [IZOD is premium clothing for everyday wear]
# 4                5       [IZOD is premium clothing for everyday wear]
# 5                5       [IZOD is premium clothing for everyday wear]
# 6                5  [Made with 75% ultra-wicking micro denier acry...
# 7                5       [IZOD is premium clothing for everyday wear]
# 8                5  [This James Dean T-shirt is a great 100% presh...
# 9                5  [SeXy 3 Piece Fishnet Set with lace trim. Whit...
#
#       item_id           price  \
# 0  B001L51C9G          $11.69
# 1  B001L5AMQU           $9.99
# 2  B001L6O1IY
# 3  B001L6PNX6
# 4  B001L6X0VI
# 5  B001L715NC
# 6  B001L6LC9U  $4.99 - $25.55
# 7  B001L711NQ
# 8  B001L7JCLY          $21.99
# 9  B001L7UQKU
#
#                                                title  \
# 0  var aPageStart = (new Date()).getTime();\nvar ...
# 1           Crew Flip Flop Tabi Casual Big Toe Socks
# 2            IZOD Women's Long Sleeve Striped Henley
# 3  IZOD Women's Raglan Long Sleeve Square Neck Wi...
# 4  IZOD Women's 3/4 Sleeve Shawl Collar Solid Pul...
# 5              IZOD Women's Flap Pocket Colored Pant
# 6                         SockGuy Men's Chains Socks
# 7  var aPageStart = (new Date()).getTime();\nvar ...
# 8  James Dean T-shirt Dream Live Adult Black Tee ...
# 9  SeXy BLACK Plus Size Bustier Camisette g-Strin...
#
#                                     url
# 0  https://www.amazon.com/dp/B001L51C9G
# 1  https://www.amazon.com/dp/B001L5AMQU
# 2  https://www.amazon.com/dp/B001L6O1IY
# 3  https://www.amazon.com/dp/B001L6PNX6
# 4  https://www.amazon.com/dp/B001L6X0VI
# 5  https://www.amazon.com/dp/B001L715NC
# 6  https://www.amazon.com/dp/B001L6LC9U
# 7  https://www.amazon.com/dp/B001L711NQ
# 8  https://www.amazon.com/dp/B001L7JCLY
# 9  https://www.amazon.com/dp/B001L7UQKU

# %%
review_dataset.limit(10).toPandas()
# Out:
#       item_id  rating   timestamp         user_id
# 0  B006CBAOQ6     1.0  1424304000  A1AG1NX2VXKY2T
# 1  B006CBAOQ6     5.0  1424304000  A3B1USQFGCWH15
# 2  B006CBAOQ6     5.0  1424044800   AXL1XBXHN1AQ1
# 3  B006CBAOQ6     4.0  1424044800   AP3CLPX9J5PAV
# 4  B006CBAOQ6     4.0  1423958400  A3REHYIAGCIFTB
# 5  B006CBAOQ6     5.0  1423267200  A2YICSVD18YH1R
# 6  B006CBAOQ6     3.0  1423094400  A3U28J1QPXC8SC
# 7  B006CBAOQ6     4.0  1422489600   ADZOZ3PZ6RLL7
# 8  B006CBAOQ6     5.0  1422489600  A1CSXM2VZLZPPA
# 9  B006CBAOQ6     5.0  1422316800  A2U3SUU8SNP8IW

# %%
review_dataset
# Out:
# DataFrame[item_id: string, rating: double, timestamp: bigint, user_id: string]

# %%
review_dataset.registerTempTable('review_dataset') 
product_subset.registerTempTable('product_subset')
query ="""
select 
    ta.user_id
from
(
    select
        ta.user_id,
        count(distinct ta.item_id, ta.timestamp) as review_count
    from
        review_dataset ta
    join
        product_subset tb
    on 
        ta.item_id=tb.item_id
    group by ta.user_id
) ta
where ta.review_count >= 20
"""
user_5core = spark.sql(query)

# %%
user_5core.count()
# Out:
# 11047

# %%
user_5core.limit(20).toPandas()
# Out:
#            user_id
# 0   A3DSSCVD3ODGQA
# 1   A3DVUL185PD63D
# 2   A21D8YZ9CDZQD7
# 3   A2VUZN3Q0H6BY7
# 4   A1YK47ZUFDBQ8Q
# 5   A2SXQ8QP7LORDO
# 6   A2ALF1CXASLJLC
# 7   A1JUWBYJ6A6RU0
# 8    APZAG6JETO1MR
# 9   A220STV60KRN7W
# 10  A20NRZZJQ2OIAR
# 11   AZWCQL30IJZR8
# 12  A1GQAKL9CGQLP1
# 13  A17PDN3EW1F05G
# 14  A2R0FNCVHMUKWH
# 15  A309G6ZUPNXXZU
# 16  A1H21U6EU1868V
# 17   AI4PP98ST4G0W
# 18  A22T2IFBAUMVYE
# 19  A3EGMDHRGLKYX2

# %%
user_5core.registerTempTable('user_5core')

query ="""
select distinct
    tb.*
from
    user_5core ta
join
    review_dataset tb
on ta.user_id=tb.user_id
"""
review_5core = spark.sql(query)

# %%
review_5core.count()
# Out:
# 614734

# %%
review_5core.limit(20).toPandas()
# Out:
#        item_id  rating   timestamp         user_id
# 0   B01E6POSZM     3.0  1503360000  A110EEWWSOHAIS
# 1   B01EM71COE     1.0  1503360000  A110EEWWSOHAIS
# 2   B00BNBB3ME     5.0  1418515200  A110EEWWSOHAIS
# 3   B00BZ4AN4S     1.0  1503360000  A110EEWWSOHAIS
# 4   B01457U2E2     5.0  1503360000  A110EEWWSOHAIS
# 5   B01C4LEWJ2     4.0  1488412800  A110EEWWSOHAIS
# 6   B002RAKPME     5.0  1503360000  A110EEWWSOHAIS
# 7   B003I8548O     5.0  1454371200  A110EEWWSOHAIS
# 8   B0048W5IHQ     4.0  1488153600  A110EEWWSOHAIS
# 9   B00NJ8C2NI     3.0  1503360000  A110EEWWSOHAIS
# 10  B00553XK3G     4.0  1488844800  A110EEWWSOHAIS
# 11  B00553XM7K     5.0  1503360000  A110EEWWSOHAIS
# 12  B00668B8KQ     2.0  1487548800  A110EEWWSOHAIS
# 13  B00CJQN66S     4.0  1488844800  A110EEWWSOHAIS
# 14  B00HUOYU2I     1.0  1512345600  A110EEWWSOHAIS
# 15  B000MOGS5K     5.0  1488844800  A110EEWWSOHAIS
# 16  B00JHDGRRG     5.0  1487548800  A110EEWWSOHAIS
# 17  B00L5YL69Y     4.0  1487548800  A110EEWWSOHAIS
# 18  B000E0ZBHS     4.0  1488844800  A110EEWWSOHAIS
# 19  B00BFWXLGM     5.0  1454371200  A110EEWWSOHAIS

# %%
review_5core.registerTempTable('review_5core')

query ="""
select distinct
    tb.*
from
    review_5core ta
join
    product_subset tb
on ta.item_id=tb.item_id
"""
product_5core = spark.sql(query)

# %%
product_5core.limit(5).toPandas()
# Out:
#          brand                                           category  \
# 0  My Michelle  [Clothing, Shoes & Jewelry, Women, Clothing, T...
# 1         Olga  [Clothing, Shoes & Jewelry, Women, Clothing, L...
# 2  Warm Things  [Clothing, Shoes & Jewelry, Women, Clothing, L...
# 3               [Clothing, Shoes & Jewelry, Women, Clothing, L...
# 4               [Clothing, Shoes & Jewelry, Women, Clothing, 9...
#
#    category_levels                                        description image  \
# 0                5                                               None
# 1                5  [This new minimizing bra provides shape and bo...
# 2                5  [Wrap yourself in the cozy comfort of the fine...
# 3                5  [Lovely embroidered mesh center Embroidered de...
# 4                5  [Today's danskin enjoys status as the ultimate...
#
#       item_id price                                              title  \
# 0  B0008G21LM             My Michelle Juniors Floral Print Ruffle Tank
# 1  B0009HN7WM        Olga Women's Sheer Tapestry Underwire Minimize...
# 2  B000B85LQE                      Warm Things Quilted Down Bed Jacket
# 3  B000EU0OSY             Lilyette by Bali  Women's Minimizer Bra #427
# 4  B000NCIGVK           Danskin Women's Revival Stovepipe Bootleg Pant
#
#                                     url
# 0  https://www.amazon.com/dp/B0008G21LM
# 1  https://www.amazon.com/dp/B0009HN7WM
# 2  https://www.amazon.com/dp/B000B85LQE
# 3  https://www.amazon.com/dp/B000EU0OSY
# 4  https://www.amazon.com/dp/B000NCIGVK

# %%
product_5core.count()
# Out:
# 107093

# %%
user_5core.write.parquet(user_path, mode='overwrite')

# %%
product_5core.write.parquet(item_path, mode='overwrite')

# %%
review_5core.write.parquet(interaction_path, mode='overwrite')

# %%
# !aws s3 ls s3://dmetasoul-bucket/sass/ecommerce/amazonfashion/dataset/
# Out:
#                            PRE amazon_fashion_interaction.parquet/
#                            PRE amazon_fashion_item.parquet/
#                            PRE amazon_fashion_user.parquet/
# 2022-09-08 14:11:37 3247339254 amazon_fashion_product.json
# 2022-09-08 14:13:55 3059298908 amazon_fashion_review.json

# %%
stop_spark(spark)
# Out:
# Debug -- spark stop
# 22/09/08 20:04:48 WARN ExecutorPodsWatchSnapshotSource: Kubernetes client has been closed (this is expected if the application is shutting down.)
